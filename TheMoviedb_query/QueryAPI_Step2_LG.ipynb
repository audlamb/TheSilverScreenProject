# %%
import requests
import json
from pprint import pprint
import pandas as pd
import time

# %%
moviecsv_data = 'TheSilverScreenProject/DataCleaning/wholelist.csv'

list_df = pd.read_csv(moviecsv_data)
list_df.head(5)
#purchase_df.count()
# Out:
#                      Award  Winner                        Film
# 0  Actor in a Leading Role     1.0                      Capote
# 1  Actor in a Leading Role     NaN               Hustle & Flow
# 2  Actor in a Leading Role     NaN          Brokeback Mountain
# 3  Actor in a Leading Role     NaN               Walk the Line
# 4  Actor in a Leading Role     NaN  Good Night, and Good Luck.

# %%
dflist = list_df['Film'].tolist()
print(dflist)
# Out:
# ['Capote', 'Hustle & Flow', 'Brokeback Mountain', 'Walk the Line', 'Good Night, and Good Luck.', 'Syriana', 'Crash', 'Cinderella Man', 'Brokeback Mountain', 'A History of Violence', 'Mrs. Henderson Presents', 'Transamerica', 'Pride & Prejudice', 'North Country', 'Walk the Line', 'Junebug', 'Capote', 'North Country', 'The Constant Gardener', 'Brokeback Mountain', 'Hayao Miyazaki', 'Mike Johnson and Tim Burton', 'Nick Park and Steve Box', 'Art Direction: Jim Bissell; Set Decoration: Jan Pascale', 'Art Direction: Stuart Craig; Set Decoration: Stephenie McMillan', 'Art Direction: Grant Major; Set Decoration: Dan Hennah and Simon Bright', 'Art Direction: John Myhre; Set Decoration: Gretchen Rau', 'Art Direction: Sarah Greenwood; Set Decoration: Katie Spencer', 'Wally Pfister', 'Rodrigo Prieto', 'Robert Elswit', 'Dion Beebe', 'Emmanuel Lubezki', 'Gabriella Pescucci', 'Colleen Atwood', 'Sandy Powell', 'Jacqueline Durran', 'Arianne Phillips', 'Ang Lee', 'Bennett Miller', 'Paul Haggis', 'George Clooney', 'Steven Spielberg', 'Hubert Sauper', 'Alex Gibney and Jason Kliot', 'Luc Jacquet and Yves Darondeau', 'Henry-Alex Rubin and Dana Adam Shapiro', 'Marshall Curry', 'Dan Krauss', 'Kimberlee Acquaro and Stacy Sherman', 'Steven Okazaki', 'Corinne Marrinan and Eric Simonson', 'Mike Hill and Dan Hanley', 'Claire Simpson', 'Hughes Winborne', 'Michael Kahn', 'Michael McCusker', 'Italy', 'France', 'The Palestinian Territories', 'Germany', 'South Africa', 'Howard Berger and Tami Lane', 'David Leroy Anderson and Lance Anderson', 'Dave Elsey and Nikki Gooley', 'Gustavo Santaolalla', 'Alberto Iglesias', 'John Williams', 'John Williams', 'Dario Marianelli', 'Music by Kathleen Bird York and Michael Becker; Lyric by Kathleen Bird York', 'Music and Lyric by Jordan Houston, Cedric Coleman and Paul Beauregard', 'Music and Lyric by Dolly Parton', 'Diana Ossana and James Schamus, Producers', 'Caroline Baron, William Vince and Michael Ohoven, Producers', 'Paul Haggis and Cathy Schulman, Producers', 'Grant Heslov, Producer', 'Kathleen Kennedy, Steven Spielberg and Barry Mendel, Producers', 'Sharon Colman', 'John Canemaker and Peggy Stern', 'Anthony Lucas', 'Shane Acker', 'Andrew Jimenez and Mark Andrews', 'Ulrike Grote', 'Sean Ellis and Lene Bausager', 'Rúnar Rúnarsson and Thor S. Sigurjónsson', 'Rob Pearlstein and Pia Clemente', 'Martin McDonagh', 'Mike Hopkins and Ethan Van der Ryn', 'Wylie Stateman', 'Richard King', 'Terry Porter, Dean A. Zupancic and Tony Johnson', 'Christopher Boyes, Michael Semanick, Michael Hedges and Hammond Peek', "Kevin O'Connell, Greg P. Russell, Rick Kline and John Pritchett", 'Paul Massey, D.M. Hemphill and Peter F. Kurland', 'Andy Nelson, Anna Behlmer and Ronald Judkins', 'Dean Wright, Bill Westenhofer, Jim Berney and Scott Farrar', "Joe Letteri, Brian Van't Hul, Christian Rivers and Richard Taylor", 'Dennis Muren, Pablo Helman, Randal M. Dutra and Daniel Sudick', 'Screenplay by Larry McMurtry & Diana Ossana', 'Screenplay by Dan Futterman', 'Screenplay by Jeffrey Caine', 'Screenplay by Josh Olson', 'Screenplay by Tony Kushner and Eric Roth', 'Screenplay by Paul Haggis & Bobby Moresco; Story by Paul Haggis', 'Screenplay by George Clooney & Grant Heslov', 'Written by Woody Allen', 'Written by Noah Baumbach', 'Written by Stephen Gaghan', nan, nan, nan, 'Blood Diamond', 'Half Nelson', 'Venus', 'The Pursuit of Happyness', 'The Last King of Scotland', 'Little Miss Sunshine', 'Little Children', 'Blood Diamond', 'Dreamgirls', 'The Departed', 'Volver', 'Notes on a Scandal', 'The Queen', 'The Devil Wears Prada', 'Little Children', 'Babel', 'Notes on a Scandal', 'Little Miss Sunshine', 'Dreamgirls', 'Babel', 'John Lasseter', 'George Miller', 'Gil Kenan', 'Art Direction: John Myhre; Set Decoration: Nancy Haigh', 'Art Direction: Jeannine Oppewall; Set Decoration: Gretchen Rau and Leslie E. Rollins', 'Art Direction: Eugenio Caballero; Set Decoration: Pilar Revuelta', 'Art Direction: Rick Heinrichs; Set Decoration: Cheryl Carasik', 'Art Direct ...

# %%
movie_list = ['Capote', 'Hustle & Flow', 'Walk the Line','Gladiator', 'the wolf of wall street', 'Up', 'The Departed']
id_list = []
url = "https://api.themoviedb.org/3/search/movie?"
api_key = "api_key=98e159931ae83a9fde8ba0f8c795951d"
search_k = "&query="

# %%
#response = requests.get(url + api_key + search_k + user_input)
#print(response.url)
call_count1 = 1
error_count = 0
sets1 = 1

# %%
for movie in dflist:
    try:
        print(f'Processing Record {call_count1} of set{sets1} | {movie}')
        response = requests.get(url + api_key + search_k + movie)
        data = response.json()
        id_list.append((data['results'][0]['id']))
        print(response.url)  
    except Exception as e:
        print(type(e))
        print(str(e))
        error_count = error_count + 1
    call_count1 = call_count1 + 1
    if call_count1 == 240:
        call_count1 = 1
        time.sleep(60)
print(f'------------------------------ \n End of Data Retrieval \n------------------------------')
print(error_count)
# Out:
# Processing Record 2 of set1 | Capote
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Capote
# Processing Record 3 of set1 | Hustle & Flow
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Hustle%20&%20Flow
# Processing Record 4 of set1 | Brokeback Mountain
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Brokeback%20Mountain
# Processing Record 5 of set1 | Walk the Line
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Walk%20the%20Line
# Processing Record 6 of set1 | Good Night, and Good Luck.
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Good%20Night,%20and%20Good%20Luck.
# Processing Record 7 of set1 | Syriana
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Syriana
# Processing Record 8 of set1 | Crash
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Crash
# Processing Record 9 of set1 | Cinderella Man
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Cinderella%20Man
# Processing Record 10 of set1 | Brokeback Mountain
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Brokeback%20Mountain
# Processing Record 11 of set1 | A History of Violence
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=A%20History%20of%20Violence
# Processing Record 12 of set1 | Mrs. Henderson Presents
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Mrs.%20Henderson%20Presents
# Processing Record 13 of set1 | Transamerica
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Transamerica
# Processing Record 14 of set1 | Pride & Prejudice
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Pride%20&%20Prejudice
# Processing Record 15 of set1 | North Country
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=North%20Country
# Processing Record 16 of set1 | Walk the Line
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Walk%20the%20Line
# Processing Record 17 of set1 | Junebug
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Junebug
# Processing Record 18 of set1 | Capote
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Capote
# Processing Record 19 of set1 | North Country
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=North%20Country
# Processing Record 20 of set1 | The Constant Gardener
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=The%20Constant%20Gardener
# Processing Record 21 of set1 | Brokeback Mountain
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Brokeback%20Mountain
# Processing Record 22 of set1 | Hayao Miyazaki
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Hayao%20Miyazaki
# Processing Record 23 of set1 | Mike Johnson and Tim Burton
# <class 'IndexError'>
# list index out of range
# Processing Record 24 of set1 | Nick Park and Steve Box
# <class 'IndexError'>
# list index out of range
# Processing Record 25 of set1 | Art Direction: Jim Bissell; Set Decoration: Jan Pascale
# <class 'IndexError'>
# list index out of range
# Processing Record 26 of set1 | Art Direction: Stuart Craig; Set Decoration: Stephenie McMillan
# <class 'IndexError'>
# list index out of range
# Processing Record 27 of set1 | Art Direction: Grant Major; Set Decoration: Dan Hennah and Simon Bright
# <class 'IndexError'>
# list index out of range
# Processing Record 28 of set1 | Art Direction: John Myhre; Set Decoration: Gretchen Rau
# <class 'IndexError'>
# list index out of range
# Processing Record 29 of set1 | Art Direction: Sarah Greenwood; Set Decoration: Katie Spencer
# <class 'IndexError'>
# list index out of range
# Processing Record 30 of set1 | Wally Pfister
# <class 'IndexError'>
# list index out of range
# Processing Record 31 of set1 | Rodrigo Prieto
# <class 'IndexError'>
# list index out of range
# Processing Record 32 of set1 | Robert Elswit
# <class 'IndexError'>
# list index out of range
# Processing Record 33 of set1 | Dion Beebe
# <class 'IndexError'>
# list index out of range
# Processing Record 34 of set1 | Emmanuel Lubezki
# <class 'IndexError'>
# list index out of range
# Processing Record 35 of set1 | Gabriella Pescucci
# <class 'IndexError'>
# list index out of range
# Processing Record 36 of set1 | Colleen Atwood
# <class 'IndexError'>
# list index out of range
# Processing Record 37 of set1 | Sandy Powell
# <class 'IndexError'>
# list index out of range
# Processing Record 38 of set1 | Jacqueline Durran
# <class 'IndexError'>
# list index out of range
# Processing Record 39 of set1 | Arianne Phillips
# <class 'IndexError'>
# list index out of range
# Processing Record 40 of set1 | Ang Lee
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Ang%20Lee
# Processing Record 41 of set1 | Bennett Miller
# <class 'IndexError'>
# list index out of range
# Processing Record 42 of set1 | Paul Haggis
# <class 'KeyError'>
# 'results'
# Processing Record 43 of set1 | George Clooney
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=George%20Clooney
# Processing Record 44 of set1 | Steven Spielberg
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Steven%20Spielberg
# Processing Record 45 of set1 | Hubert Sauper
# <class 'IndexError'>
# list index out of range
# Processing Record 46 of set1 | Alex Gibney and Jason Kliot
# <class 'IndexError'>
# list index out of range
# Processing Record 47 of set1 | Luc Jacquet and Yves Darondeau
# <class 'IndexError'>
# list index out of range
# Processing Record 48 of set1 | Henry-Alex Rubin and Dana Adam Shapiro
# <class 'IndexError'>
# list index out of range
# Processing Record 49 of set1 | Marshall Curry
# <class 'IndexError'>
# list index out of range
# Processing Record 50 of set1 | Dan Krauss
# <class 'IndexError'>
# list index out of range
# Processing Record 51 of set1 | Kimberlee Acquaro and Stacy Sherman
# <class 'IndexError'>
# list index out of range
# Processing Record 52 of set1 | Steven Okazaki
# <class 'IndexError'>
# list index out of range
# Processing Record 53 of set1 | Corinne Marrinan and Eric Simonson
# <class 'IndexError'>
# list index out of range
# Processing Record 54 of set1 | Mike Hill and Dan Hanley
# <class 'IndexError'>
# list index out of range
# Processing Record 55 of set1 | Claire Simpson
# <class 'IndexError'>
# list index out of range
# Processing Record 56 of set1 | Hughes Winborne
# <class 'IndexError'>
# list index out of range
# Processing Record 57 of set1 | Michael Kahn
# <class 'IndexError'>
# list index out of range
# Processing Record 58 of set1 | Michael McCusker
# <class 'IndexError'>
# list index out of range
# Processing Record 59 of set1 | Italy
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Italy
# Processing Record 60 of set1 | France
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=France
# Processing Record 61 of set1 | The Palestinian Territories
# <class 'IndexError'>
# list index out of range
# Processing Record 62 of set1 | Germany
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Germany
# Processing Record 63 of set1 | South Africa
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=South%20Africa
# Processing Record 64 of set1 | Howard Berger and Tami Lane
# <class 'IndexError'>
# list index out of range
# Processing Record 65 of set1 | David Leroy Anderson and Lance Anderson
# <class 'IndexError'>
# list index out of range
# Processing Record 66 of set1 | Dave Elsey and Nikki Gooley
# <class 'IndexError'>
# list index out of range
# Processing Record 67 of set1 | Gustavo Santaolalla
# <class 'IndexError'>
# list index out of range
# Processing Record 68 of set1 | Alberto Iglesias
# <class 'IndexError'>
# list index out of range
# Processing Record 69 of set1 | John Williams
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=John%20Williams
# Processing Record 70 of set1 | John Williams
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=John%20Williams
# Processing Record 71 of set1 | Dario Marianelli
# <class 'IndexError'>
# list index out of range
# Processing Record 72 of set1 | Music by Kathleen Bird York and Michael Becker; Lyric by Kathleen Bird York
# <class 'IndexError'>
# list index out of range
# Processing Record 73 of set1 | Music and Lyric by Jordan Houston, Cedric Coleman and Paul Beauregard
# <class 'IndexError'>
# list index out of range
# Processing Record 74 of set1 | Music and Lyric by Dolly Parton
# <class 'IndexError'>
# list index out of range
# Processing Record 75 of set1 | Diana Ossana and James Schamus, Producers
# <class 'IndexError'>
# list index out of range
# Processing Record 76 of set1 | Caroline Baron, William Vince and Michael Ohoven, Producers
# <class 'IndexError'>
# list index out of range
# Processing Record 77 of set1 | Paul Haggis and Cathy Schulman, Producers
# <class 'IndexError'>
# list index out of range
# Processing Record 78 of set1 | Grant Heslov, Producer
# <class 'IndexError'>
# list index out of range
# Processing Record 79 of set1 | Kathleen Kennedy, Steven Spielberg and Barry Mendel, Producers
# <class 'IndexError'>
# list index out of range
# Processing Record 80 of set1 | Sharon Colman
# <class 'IndexError'>
# list index out of range
# Processing Record 81 of set1 | John Canemaker and Peggy Stern
# <class 'IndexError'>
# list index out of range
# Processing Record 82 of set1 | Anthony Lucas
# <class 'IndexError'>
# list index out of range
# Processing Record 83 of set1 | Shane Acker
# <class 'KeyError'>
# 'results'
# Processing Record 84 of set1 | Andrew Jimenez and Mark Andrews
# <class 'KeyError'>
# 'results'
# Processing Record 85 of set1 | Ulrike Grote
# <class 'IndexError'>
# list index out of range
# Processing Record 86 of set1 | Sean Ellis and Lene Bausager
# <class 'IndexError'>
# list index out of range
# Processing Record 87 of set1 | Rúnar Rúnarsson and Thor S. Sigurjónsson
# <class 'IndexError'>
# list index out of range
# Processing Record 88 of set1 | Rob Pearlstein and Pia Clemente
# <class 'IndexError'>
# list index out of range
# Processing Record 89 of set1 | Martin McDonagh
# <class 'IndexError'>
# list index out of range
# Processing Record 90 of set1 | Mike Hopkins and Ethan Van der Ryn
# <class 'IndexError'>
# list index out of range
# Processing Record 91 of set1 | Wylie Stateman
# <class 'IndexError'>
# list index out of range
# Processing Record 92 of set1 | Richard King
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Richard%20King
# Processing Record 93 of set1 | Terry Porter, Dean A. Zupancic and Tony Johnson
# <class 'IndexError'>
# list index out of range
# Processing Record 94 of set1 | Christopher Boyes, Michael Semanick, Michael Hedges and Hammond Peek
# <class 'IndexError'>
# list index out of range
# Processing Record 95 of set1 | Kevin O'Connell, Greg P. Russell, Rick Kline and John Pritchett
# <class 'IndexError'>
# list index out of range
# Processing Record 96 of set1 | Paul Massey, D.M. Hemphill and Peter F. Kurland
# <class 'IndexError'>
# list index out of range
# Processing Record 97 of set1 | Andy Nelson, Anna Behlmer and Ronald Judkins
# <class 'IndexError'>
# list index out of range
# Processing Record 98 of set1 | Dean Wright, Bill Westenhofer, Jim Berney and Scott Farrar
# <class 'IndexError'>
# list index out of range
# Processing Record 99 of set1 | Joe Letteri, Brian Van't Hul, Christian Rivers and Richard Taylor
# <class 'IndexError'>
# list index out of range
# Processing Record 100 of set1 | Dennis Muren, Pablo Helman, Randal M. Dutra and Daniel Sudick
# <class 'IndexError'>
# list index out of range
# Processing Record 101 of set1 | Screenplay by Larry McMurtry & Diana Ossana
# <class 'IndexError'>
# list index out of range
# Processing Record 102 of set1 | Screenplay by Dan Futterman
# <class 'IndexError'>
# list index out of range
# Processing Record 103 of set1 | Screenplay by Jeffrey Caine
# <class 'IndexError'>
# list index out of range
# Processing Record 104 of set1 | Screenplay by Josh Olson
# <class 'IndexError'>
# list index out of range
# Processing Record 105 of set1 | Screenplay by Tony Kushner and Eric Roth
# <class 'IndexError'>
# list index out of range
# Processing Record 106 of set1 | Screenplay by Paul Haggis & Bobby Moresco; Story by Paul Haggis
# <class 'IndexError'>
# list index out of range
# Processing Record 107 of set1 | Screenplay by George Clooney & Grant Heslov
# <class 'IndexError'>
# list index out of range
# Processing Record 108 of set1 | Written by Woody Allen
# <class 'IndexError'>
# list index out of range
# Processing Record 109 of set1 | Written by Noah Baumbach
# <class 'IndexError'>
# list index out of range
# Processing Record 110 of set1 | Written by Stephen Gaghan
# <class 'IndexError'>
# list index out of range
# Processing Record 111 of set1 | nan
# <class 'TypeError'>
# must be str, not float
# Processing Record 112 of set1 | nan
# <class 'TypeError'>
# must be str, not float
# Processing Record 113 of set1 | nan
# <class 'TypeError'>
# must be str, not float
# Processing Record 114 of set1 | Blood Diamond
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Blood%20Diamond
# Processing Record 115 of set1 | Half Nelson
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Half%20Nelson
# Processing Record 116 of set1 | Venus
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Venus
# Processing Record 117 of set1 | The Pursuit of Happyness
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=The%20Pursuit%20of%20Happyness
# Processing Record 118 of set1 | The Last King of Scotland
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=The%20Last%20King%20of%20Scotland
# Processing Record 119 of set1 | Little Miss Sunshine
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Little%20Miss%20Sunshine
# Processing Record 120 of set1 | Little Children
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Little%20Children
# Processing Record 121 of set1 | Blood Diamond
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Blood%20Diamond
# Processing Record 122 of set1 | Dreamgirls
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Dreamgirls
# Processing Record 123 of set1 | The Departed
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=The%20Departed
# Processing Record 124 of set1 | Volver
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Volver
# Processing Record 125 of set1 | Notes on a Scandal
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Notes%20on%20a%20Scandal
# Processing Record 126 of set1 | The Queen
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=The%20Queen
# Processing Record 127 of set1 | The Devil Wears Prada
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=The%20Devil%20Wears%20Prada
# Processing Record 128 of set1 | Little Children
# <class 'KeyError'>
# 'results'
# Processing Record 129 of set1 | Babel
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Babel
# Processing Record 130 of set1 | Notes on a Scandal
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Notes%20on%20a%20Scandal
# Processing Record 131 of set1 | Little Miss Sunshine
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Little%20Miss%20Sunshine
# Processing Record 132 of set1 | Dreamgirls
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Dreamgirls
# Processing Record 133 of set1 | Babel
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Babel
# Processing Record 134 of set1 | John Lasseter
# <class 'IndexError'>
# list index out of range
# Processing Record 135 of set1 | George Miller
# <class 'IndexError'>
# list index out of range
# Processing Record 136 of set1 | Gil Kenan
# <class 'IndexError'>
# list index out of range
# Processing Record 137 of set1 | Art Direction: John Myhre; Set Decoration: Nancy Haigh
# <class 'IndexError'>
# list index out of range
# Processing Record 138 of set1 | Art Direction: Jeannine Oppewall; Set Decoration: Gretchen Rau and Leslie E. Rollins
# <class 'IndexError'>
# list index out of range
# Processing Record 139 of set1 | Art Direction: Eugenio Caballero; Set Decoration: Pilar Revuelta
# <class 'IndexError'>
# list index out of range
# Processing Record 140 of set1 | Art Direction: Rick Heinrichs; Set Decoration: Cheryl Carasik
# <class 'IndexError'>
# list index out of range
# Processing Record 141 of set1 | Art Direction: Nathan Crowley; Set Decoration: Julie Ochipinti
# <class 'IndexError'>
# list index out of range
# Processing Record 142 of set1 | Vilmos Zsigmond
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Vilmos%20Zsigmond
# Processing Record 143 of set1 | Emmanuel Lubezki
# <class 'IndexError'>
# list index out of range
# Processing Record 144 of set1 | Dick Pope
# <class 'IndexError'>
# list index out of range
# Processing Record 145 of set1 | Guillermo Navarro
# <class 'IndexError'>
# list index out of range
# Processing Record 146 of set1 | Wally Pfister
# <class 'IndexError'>
# list index out of range
# Processing Record 147 of set1 | Yee Chung Man
# <class 'IndexError'>
# list index out of range
# Processing Record 148 of set1 | Patricia Field
# <class 'IndexError'>
# list index out of range
# Processing Record 149 of set1 | Sharen Davis
# <class 'IndexError'>
# list index out of range
# Processing Record 150 of set1 | Milena Canonero
# <class 'IndexError'>
# list index out of range
# Processing Record 151 of set1 | Consolata Boyle
# <class 'IndexError'>
# list index out of range
# Processing Record 152 of set1 | Alejandro González Iñárritu
# <class 'IndexError'>
# list index out of range
# Processing Record 153 of set1 | Martin Scorsese
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Martin%20Scorsese
# Processing Record 154 of set1 | Clint Eastwood
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Clint%20Eastwood
# Processing Record 155 of set1 | Stephen Frears
# <class 'IndexError'>
# list index out of range
# Processing Record 156 of set1 | Paul Greengrass
# <class 'IndexError'>
# list index out of range
# Processing Record 157 of set1 | Amy Berg and Frank Donner
# <class 'IndexError'>
# list index out of range
# Processing Record 158 of set1 | Davis Guggenheim
# <class 'IndexError'>
# list index out of range
# Processing Record 159 of set1 | James Longley and John Sinno
# <class 'IndexError'>
# list index out of range
# Processing Record 160 of set1 | Heidi Ewing and Rachel Grady
# <class 'IndexError'>
# list index out of range
# Processing Record 161 of set1 | Laura Poitras and Jocelyn Glatzer
# <class 'IndexError'>
# list index out of range
# Processing Record 162 of set1 | Ruby Yang and Thomas Lennon
# <class 'IndexError'>
# list index out of range
# Processing Record 163 of set1 | Leslie Iwerks and Mike Glad
# <class 'IndexError'>
# list index out of range
# Processing Record 164 of set1 | Karen Goodman and Kirk Simon
# <class 'IndexError'>
# list index out of range
# Processing Record 165 of set1 | Nathaniel Kahn and Susan Rose Behr
# <class 'IndexError'>
# list index out of range
# Processing Record 166 of set1 | Stephen Mirrione and Douglas Crise
# <class 'IndexError'>
# list index out of range
# Processing Record 167 of set1 | Steven Rosenblum
# <class 'IndexError'>
# list index out of range
# Processing Record 168 of set1 | Alex Rodríguez and Alfonso Cuarón
# <class 'IndexError'>
# list index out of range
# Processing Record 169 of set1 | Thelma Schoonmaker
# <class 'IndexError'>
# list index out of range
# Processing Record 170 of set1 | Clare Douglas, Christopher Rouse and Richard Pearson
# <class 'IndexError'>
# list index out of range
# Processing Record 171 of set1 | Denmark
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Denmark
# Processing Record 172 of set1 | Algeria
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Algeria
# Processing Record 173 of set1 | Germany
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Germany
# Processing Record 174 of set1 | Mexico
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Mexico
# Processing Record 175 of set1 | Canada
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Canada
# Processing Record 176 of set1 | Aldo Signoretti and Vittorio Sodano
# <class 'IndexError'>
# list index out of range
# Processing Record 177 of set1 | Kazuhiro Tsuji and Bill Corso
# <class 'IndexError'>
# list index out of range
# Processing Record 178 of set1 | David Martí and Montse Ribé
# <class 'IndexError'>
# list index out of range
# Processing Record 179 of set1 | Gustavo Santaolalla
# <class 'IndexError'>
# list index out of range
# Processing Record 180 of set1 | Thomas Newman
# <class 'IndexError'>
# list index out of range
# Processing Record 181 of set1 | Philip Glass
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Philip%20Glass
# Processing Record 182 of set1 | Javier Navarrete
# <class 'IndexError'>
# list index out of range
# Processing Record 183 of set1 | Alexandre Desplat
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Alexandre%20Desplat
# Processing Record 184 of set1 | Music and Lyric by Melissa Etheridge
# <class 'IndexError'>
# list index out of range
# Processing Record 185 of set1 | Music by Henry Krieger and Scott Cutler; Lyric by Anne Preven
# <class 'IndexError'>
# list index out of range
# Processing Record 186 of set1 | Music by Henry Krieger; Lyric by Siedah Garrett
# <class 'IndexError'>
# list index out of range
# Processing Record 187 of set1 | Music and Lyric by Randy Newman
# <class 'IndexError'>
# list index out of range
# Processing Record 188 of set1 | Music by Henry Krieger; Lyric by Willie Reale
# <class 'IndexError'>
# list index out of range
# Processing Record 189 of set1 | Alejandro González Iñárritu, Jon Kilik and Steve Golin, Producers
# <class 'IndexError'>
# list index out of range
# Processing Record 190 of set1 | Graham King, Producer
# <class 'IndexError'>
# list index out of range
# Processing Record 191 of set1 | Clint Eastwood, Steven Spielberg and Robert Lorenz, Producers
# <class 'IndexError'>
# list index out of range
# Processing Record 192 of set1 | David T. Friendly, Peter Saraf and Marc Turtletaub, Producers
# <class 'IndexError'>
# list index out of range
# Processing Record 193 of set1 | Andy Harries, Christine Langan and Tracey Seaward, Producers
# <class 'IndexError'>
# list index out of range
# Processing Record 194 of set1 | Torill Kove
# <class 'IndexError'>
# list index out of range
# Processing Record 195 of set1 | Gary Rydstrom
# <class 'IndexError'>
# list index out of range
# Processing Record 196 of set1 | Roger Allers and Don Hahn
# <class 'IndexError'>
# list index out of range
# Processing Record 197 of set1 | Géza M. Tóth
# <class 'IndexError'>
# list index out of range
# Processing Record 198 of set1 | Chris Renaud and Michael Thurmeier
# <class 'IndexError'>
# list index out of range
# Processing Record 199 of set1 | Javier Fesser and Luis Manso
# <class 'IndexError'>
# list index out of range
# Processing Record 200 of set1 | Borja Cobeaga
# <class 'IndexError'>
# list index out of range
# Processing Record 201 of set1 | Søren Pilmark and Kim Magnusson
# <class 'IndexError'>
# list index out of range
# Processing Record 202 of set1 | Peter Templeman and Stuart Parkyn
# <class 'IndexError'>
# list index out of range
# Processing Record 203 of set1 | Ari Sandel
# <class 'IndexError'>
# list index out of range
# Processing Record 204 of set1 | Sean McCormack and Kami Asgar
# <class 'IndexError'>
# list index out of range
# Processing Record 205 of set1 | Lon Bender
# <class 'IndexError'>
# list index out of range
# Processing Record 206 of set1 | Alan Robert Murray and Bub Asman
# <class 'IndexError'>
# list index out of range
# Processing Record 207 of set1 | Alan Robert Murray and Bub Asman
# <class 'IndexError'>
# list index out of range
# Processing Record 208 of set1 | Christopher Boyes and George Watters II
# <class 'IndexError'>
# list index out of range
# Processing Record 209 of set1 | Kevin O'Connell, Greg P. Russell and Fernando Cámara
# <class 'IndexError'>
# list index out of range
# Processing Record 210 of set1 | Andy Nelson, Anna Behlmer and Ivan Sharrock
# <class 'IndexError'>
# list index out of range
# Processing Record 211 of set1 | Michael Minkler, Bob Beemer and Willie Burton
# <class 'IndexError'>
# list index out of range
# Processing Record 212 of set1 | John Reitz, Dave Campbell, Gregg Rudloff and Walt Martin
# <class 'IndexError'>
# list index out of range
# Processing Record 213 of set1 | Paul Massey, Christopher Boyes and Lee Orloff
# <class 'IndexError'>
# list index out of range
# Processing Record 214 of set1 | John Knoll, Hal Hickel, Charles Gibson and Allen Hall
# <class 'IndexError'>
# list index out of range
# Processing Record 215 of set1 | Boyd Shermis, Kim Libreri, Chas Jarrett and John Frazier
# <class 'IndexError'>
# list index out of range
# Processing Record 216 of set1 | Mark Stetson, Neil Corbould, Richard R. Hoover and Jon Thum
# <class 'IndexError'>
# list index out of range
# Processing Record 217 of set1 | Screenplay by Sacha Baron Cohen & Anthony Hines & Peter Baynham & Dan Mazer; Story by Sacha Baron Cohen & Peter Baynham & Anthony Hines & Todd Phillips
# <class 'IndexError'>
# list index out of range
# Processing Record 218 of set1 | Screenplay by Alfonso Cuarón & Timothy J. Sexton and David Arata and Mark Fergus & Hawk Ostby
# <class 'IndexError'>
# list index out of range
# Processing Record 219 of set1 | Screenplay by William Monahan
# <class 'IndexError'>
# list index out of range
# Processing Record 220 of set1 | Screenplay by Todd Field & Tom Perrotta
# <class 'IndexError'>
# list index out of range
# Processing Record 221 of set1 | Screenplay by Patrick Marber
# <class 'IndexError'>
# list index out of range
# Processing Record 222 of set1 | Written by Guillermo Arriaga
# <class 'IndexError'>
# list index out of range
# Processing Record 223 of set1 | Screenplay by Iris Yamashita; Story by Iris Yamashita & Paul Haggis
# <class 'IndexError'>
# list index out of range
# Processing Record 224 of set1 | Written by Michael Arndt
# <class 'IndexError'>
# list index out of range
# Processing Record 225 of set1 | Written by Guillermo del Toro
# <class 'IndexError'>
# list index out of range
# Processing Record 226 of set1 | Written by Peter Morgan
# <class 'IndexError'>
# list index out of range
# Processing Record 227 of set1 | nan
# <class 'TypeError'>
# must be str, not float
# Processing Record 228 of set1 | nan
# <class 'TypeError'>
# must be str, not float
# Processing Record 229 of set1 | nan
# <class 'TypeError'>
# must be str, not float
# Processing Record 230 of set1 | nan
# <class 'TypeError'>
# must be str, not float
# Processing Record 231 of set1 | nan
# <class 'TypeError'>
# must be str, not float
# Processing Record 232 of set1 | Michael Clayton
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Michael%20Clayton
# Processing Record 233 of set1 | There Will Be Blood
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=There%20Will%20Be%20Blood
# Processing Record 234 of set1 | Sweeney Todd The Demon Barber of Fleet Street
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Sweeney%20Todd%20The%20Demon%20Barber%20of%20Fleet%20Street
# Processing Record 235 of set1 | In the Valley of Elah
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=In%20the%20Valley%20of%20Elah
# Processing Record 236 of set1 | Eastern Promises
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Eastern%20Promises
# Processing Record 237 of set1 | The Assassination of Jesse James by the Coward Robert Ford
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=The%20Assassination%20of%20Jesse%20James%20by%20the%20Coward%20Robert%20Ford
# Processing Record 238 of set1 | No Country for Old Men
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=No%20Country%20for%20Old%20Men
# Processing Record 239 of set1 | Charlie Wilson's War
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Charlie%20Wilson's%20War
# Processing Record 1 of set1 | Into the Wild
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Into%20the%20Wild
# Processing Record 2 of set1 | Michael Clayton
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Michael%20Clayton
# Processing Record 3 of set1 | Elizabeth: The Golden Age
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Elizabeth:%20The%20Golden%20Age
# Processing Record 4 of set1 | Away from Her
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Away%20from%20Her
# Processing Record 5 of set1 | La Vie en Rose
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=La%20Vie%20en%20Rose
# Processing Record 6 of set1 | The Savages
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=The%20Savages
# Processing Record 7 of set1 | Juno
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Juno
# Processing Record 8 of set1 | I'm Not There
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=I'm%20Not%20There
# Processing Record 9 of set1 | American Gangster
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=American%20Gangster
# Processing Record 10 of set1 | Atonement
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Atonement
# Processing Record 11 of set1 | Gone Baby Gone
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Gone%20Baby%20Gone
# Processing Record 12 of set1 | Michael Clayton
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Michael%20Clayton
# Processing Record 13 of set1 | Marjane Satrapi and Vincent Paronnaud
# <class 'IndexError'>
# list index out of range
# Processing Record 14 of set1 | Brad Bird
# <class 'IndexError'>
# list index out of range
# Processing Record 15 of set1 | Ash Brannon and Chris Buck
# <class 'IndexError'>
# list index out of range
# Processing Record 16 of set1 | Art Direction: Arthur Max; Set Decoration: Beth A. Rubino
# <class 'IndexError'>
# list index out of range
# Processing Record 17 of set1 | Art Direction: Sarah Greenwood; Set Decoration: Katie Spencer
# <class 'IndexError'>
# list index out of range
# Processing Record 18 of set1 | Art Direction: Dennis Gassner; Set Decoration: Anna Pinnock
# <class 'IndexError'>
# list index out of range
# Processing Record 19 of set1 | Art Direction: Dante Ferretti; Set Decoration: Francesca Lo Schiavo
# <class 'IndexError'>
# list index out of range
# Processing Record 20 of set1 | Art Direction: Jack Fisk; Set Decoration: Jim Erickson
# <class 'IndexError'>
# list index out of range
# Processing Record 21 of set1 | Roger Deakins
# <class 'IndexError'>
# list index out of range
# Processing Record 22 of set1 | Seamus McGarvey
# <class 'IndexError'>
# list index out of range
# Processing Record 23 of set1 | Janusz Kaminski
# <class 'IndexError'>
# list index out of range
# Processing Record 24 of set1 | Roger Deakins
# <class 'IndexError'>
# list index out of range
# Processing Record 25 of set1 | Robert Elswit
# <class 'IndexError'>
# list index out of range
# Processing Record 26 of set1 | Albert Wolsky
# <class 'IndexError'>
# list index out of range
# Processing Record 27 of set1 | Jacqueline Durran
# <class 'IndexError'>
# list index out of range
# Processing Record 28 of set1 | Alexandra Byrne
# <class 'IndexError'>
# list index out of range
# Processing Record 29 of set1 | Marit Allen
# <class 'IndexError'>
# list index out of range
# Processing Record 30 of set1 | Colleen Atwood
# <class 'IndexError'>
# list index out of range
# Processing Record 31 of set1 | Julian Schnabel
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Julian%20Schnabel
# Processing Record 32 of set1 | Jason Reitman
# <class 'IndexError'>
# list index out of range
# Processing Record 33 of set1 | Tony Gilroy
# <class 'IndexError'>
# list index out of range
# Processing Record 34 of set1 | Joel Coen and Ethan Coen
# <class 'IndexError'>
# list index out of range
# Processing Record 35 of set1 | Paul Thomas Anderson
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Paul%20Thomas%20Anderson
# Processing Record 36 of set1 | Charles Ferguson and Audrey Marrs
# <class 'IndexError'>
# list index out of range
# Processing Record 37 of set1 | Richard E. Robbins
# <class 'IndexError'>
# list index out of range
# Processing Record 38 of set1 | Michael Moore and Meghan O'Hara
# <class 'IndexError'>
# list index out of range
# Processing Record 39 of set1 | Alex Gibney and Eva Orner
# <class 'IndexError'>
# list index out of range
# Processing Record 40 of set1 | Andrea Nix Fine and Sean Fine
# <class 'IndexError'>
# list index out of range
# Processing Record 41 of set1 | Cynthia Wade and Vanessa Roth
# <class 'KeyError'>
# 'results'
# Processing Record 42 of set1 | Amanda Micheli and Isabel Vega
# <class 'KeyError'>
# 'results'
# Processing Record 43 of set1 | Tim Sternberg and Francisco Bello
# <class 'KeyError'>
# 'results'
# Processing Record 44 of set1 | James Longley
# <class 'IndexError'>
# list index out of range
# Processing Record 45 of set1 | Christopher Rouse
# <class 'IndexError'>
# list index out of range
# Processing Record 46 of set1 | Juliette Welfling
# <class 'IndexError'>
# list index out of range
# Processing Record 47 of set1 | Jay Cassidy
# <class 'IndexError'>
# list index out of range
# Processing Record 48 of set1 | Roderick Jaynes
# <class 'IndexError'>
# list index out of range
# Processing Record 49 of set1 | Dylan Tichenor
# <class 'IndexError'>
# list index out of range
# Processing Record 50 of set1 | Israel
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Israel
# Processing Record 51 of set1 | Austria
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Austria
# Processing Record 52 of set1 | Poland
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Poland
# Processing Record 53 of set1 | Kazakhstan
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Kazakhstan
# Processing Record 54 of set1 | Russia
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Russia
# Processing Record 55 of set1 | Didier Lavergne and Jan Archibald
# <class 'IndexError'>
# list index out of range
# Processing Record 56 of set1 | Rick Baker and Kazuhiro Tsuji
# <class 'IndexError'>
# list index out of range
# Processing Record 57 of set1 | Ve Neill and Martin Samuel
# <class 'IndexError'>
# list index out of range
# Processing Record 58 of set1 | Dario Marianelli
# <class 'IndexError'>
# list index out of range
# Processing Record 59 of set1 | Alberto Iglesias
# <class 'IndexError'>
# list index out of range
# Processing Record 60 of set1 | James Newton Howard
# <class 'IndexError'>
# list index out of range
# Processing Record 61 of set1 | Michael Giacchino
# <class 'IndexError'>
# list index out of range
# Processing Record 62 of set1 | Marco Beltrami
# <class 'IndexError'>
# list index out of range
# Processing Record 63 of set1 | Music and Lyric by Glen Hansard and Marketa Irglova
# <class 'IndexError'>
# list index out of range
# Processing Record 64 of set1 | Music by Alan Menken; Lyric by Stephen Schwartz
# <class 'IndexError'>
# list index out of range
# Processing Record 65 of set1 | Music and Lyric by Jamal Joseph, Charles Mack and Tevin Thomas
# <class 'IndexError'>
# list index out of range
# Processing Record 66 of set1 | Music by Alan Menken; Lyric by Stephen Schwartz
# <class 'IndexError'>
# list index out of range
# Processing Record 67 of set1 | Music by Alan Menken; Lyric by Stephen Schwartz
# <class 'IndexError'>
# list index out of range
# Processing Record 68 of set1 | Tim Bevan, Eric Fellner and Paul Webster, Producers
# <class 'IndexError'>
# list index out of range
# Processing Record 69 of set1 | Lianne Halfon, Mason Novick and Russell Smith, Producers
# <class 'IndexError'>
# list index out of range
# Processing Record 70 of set1 | Sydney Pollack, Jennifer Fox and Kerry Orent, Producers
# <class 'IndexError'>
# list index out of range
# Processing Record 71 of set1 | Scott Rudin, Ethan Coen and Joel Coen, Producers
# <class 'IndexError'>
# list index out of range
# Processing Record 72 of set1 | JoAnne Sellar, Paul Thomas Anderson and Daniel Lupi, Producers
# <class 'IndexError'>
# list index out of range
# Processing Record 73 of set1 | Josh Raskin
# <class 'IndexError'>
# list index out of range
# Processing Record 74 of set1 | Chris Lavis and Maciek Szczerbowski
# <class 'IndexError'>
# list index out of range
# Processing Record 75 of set1 | Samuel Tourneux and Simon Vanesse
# <class 'IndexError'>
# list index out of range
# Processing Record 76 of set1 | Alexander Petrov
# <class 'IndexError'>
# list index out of range
# Processing Record 77 of set1 | Suzie Templeton and Hugh Welchman
# <class 'IndexError'>
# list index out of range
# Processing Record 78 of set1 | Christian E. Christiansen and Louise Vesth
# <class 'IndexError'>
# list index out of range
# Processing Record 79 of set1 | Andrea Jublin
# <class 'IndexError'>
# list index out of range
# Processing Record 80 of set1 | Philippe Pollet-Villard
# <class 'IndexError'>
# list index out of range
# Processing Record 81 of set1 | Guido Thys and Anja Daelemans
# <class 'IndexError'>
# list index out of range
# Processing Record 82 of set1 | Daniel Barber and Matthew Brown
# <class 'IndexError'>
# list index out of range
# Processing Record 83 of set1 | Karen Baker Landers and Per Hallberg
# <class 'IndexError'>
# list index out of range
# Processing Record 84 of set1 | Skip Lievsay
# <class 'KeyError'>
# 'results'
# Processing Record 85 of set1 | Randy Thom and Michael Silvers
# <class 'KeyError'>
# 'results'
# Processing Record 86 of set1 | Christopher Scarabosio and Matthew Wood
# <class 'IndexError'>
# list index out of range
# Processing Record 87 of set1 | Ethan Van der Ryn and Mike Hopkins
# <class 'IndexError'>
# list index out of range
# Processing Record 88 of set1 | Scott Millan, David Parker and Kirk Francis
# <class 'IndexError'>
# list index out of range
# Processing Record 89 of set1 | Skip Lievsay, Craig Berkey, Greg Orloff and Peter Kurland
# <class 'IndexError'>
# list index out of range
# Processing Record 90 of set1 | Randy Thom, Michael Semanick and Doc Kane
# <class 'IndexError'>
# list index out of range
# Processing Record 91 of set1 | Paul Massey, David Giammarco and Jim Stuebe
# <class 'IndexError'>
# list index out of range
# Processing Record 92 of set1 | Kevin O'Connell, Greg P. Russell and Peter J. Devlin
# <class 'IndexError'>
# list index out of range
# Processing Record 93 of set1 | Michael Fink, Bill Westenhofer, Ben Morris and Trevor Wood
# <class 'IndexError'>
# list index out of range
# Processing Record 94 of set1 | John Knoll, Hal Hickel, Charles Gibson and John Frazier
# <class 'IndexError'>
# list index out of range
# Processing Record 95 of set1 | Scott Farrar, Scott Benza, Russell Earl and John Frazier
# <class 'IndexError'>
# list index out of range
# Processing Record 96 of set1 | Screenplay by Christopher Hampton
# <class 'IndexError'>
# list index out of range
# Processing Record 97 of set1 | Written by Sarah Polley
# <class 'IndexError'>
# list index out of range
# Processing Record 98 of set1 | Screenplay by Ronald Harwood
# <class 'IndexError'>
# list index out of range
# Processing Record 99 of set1 | Written for the screen by Joel Coen & Ethan Coen
# <class 'IndexError'>
# list index out of range
# Processing Record 100 of set1 | Written for the Screen by Paul Thomas Anderson
# <class 'IndexError'>
# list index out of range
# Processing Record 101 of set1 | Written by Diablo Cody
# <class 'IndexError'>
# list index out of range
# Processing Record 102 of set1 | Written by Nancy Oliver
# <class 'IndexError'>
# list index out of range
# Processing Record 103 of set1 | Written by Tony Gilroy
# <class 'IndexError'>
# list index out of range
# Processing Record 104 of set1 | Screenplay by Brad Bird; Story by Jan Pinkava, Jim Capobianco, Brad Bird
# <class 'IndexError'>
# list index out of range
# Processing Record 105 of set1 | Written by Tamara Jenkins
# <class 'IndexError'>
# list index out of range
# Processing Record 106 of set1 | nan
# <class 'TypeError'>
# must be str, not float
# Processing Record 107 of set1 | nan
# <class 'TypeError'>
# must be str, not float
# Processing Record 108 of set1 | nan
# <class 'TypeError'>
# must be str, not float
# Processing Record 109 of set1 | nan
# <class 'TypeError'>
# must be str, not float
# Processing Record 110 of set1 | The Visitor
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=The%20Visitor
# Processing Record 111 of set1 | Frost/Nixon
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Frost/Nixon
# Processing Record 112 of set1 | Milk
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Milk
# Processing Record 113 of set1 | The Curious Case of Benjamin Button
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=The%20Curious%20Case%20of%20Benjamin%20Button
# Processing Record 114 of set1 | The Wrestler
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=The%20Wrestler
# Processing Record 115 of set1 | Milk
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Milk
# Processing Record 116 of set1 | Tropic Thunder
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Tropic%20Thunder
# Processing Record 117 of set1 | Doubt
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Doubt
# Processing Record 118 of set1 | The Dark Knight
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=The%20Dark%20Knight
# Processing Record 119 of set1 | Revolutionary Road
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Revolutionary%20Road
# Processing Record 120 of set1 | Rachel Getting Married
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Rachel%20Getting%20Married
# Processing Record 121 of set1 | Changeling
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Changeling
# Processing Record 122 of set1 | Frozen River
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Frozen%20River
# Processing Record 123 of set1 | Doubt
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Doubt
# Processing Record 124 of set1 | The Reader
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=The%20Reader
# Processing Record 125 of set1 | Doubt
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Doubt
# Processing Record 126 of set1 | Vicky Cristina Barcelona
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Vicky%20Cristina%20Barcelona
# Processing Record 127 of set1 | Doubt
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Doubt
# Processing Record 128 of set1 | The Curious Case of Benjamin Button
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=The%20Curious%20Case%20of%20Benjamin%20Button
# Processing Record 129 of set1 | The Wrestler
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=The%20Wrestler
# Processing Record 130 of set1 | Chris Williams and Byron Howard
# <class 'IndexError'>
# list index out of range
# Processing Record 131 of set1 | John Stevenson and Mark Osborne
# <class 'IndexError'>
# list index out of range
# Processing Record 132 of set1 | Andrew Stanton
# <class 'IndexError'>
# list index out of range
# Processing Record 133 of set1 | Art Direction: James J. Murakami; Set Decoration: Gary Fettis
# <class 'IndexError'>
# list index out of range
# Processing Record 134 of set1 | Art Direction: Donald Graham Burt; Set Decoration: Victor J. Zolfo
# <class 'IndexError'>
# list index out of range
# Processing Record 135 of set1 | Art Direction: Nathan Crowley; Set Decoration: Peter Lando
# <class 'IndexError'>
# list index out of range
# Processing Record 136 of set1 | Art Direction: Michael Carlin; Set Decoration: Rebecca Alleway
# <class 'IndexError'>
# list index out of range
# Processing Record 137 of set1 | Art Direction: Kristi Zea; Set Decoration: Debra Schutt
# <class 'IndexError'>
# list index out of range
# Processing Record 138 of set1 | Tom Stern
# <class 'IndexError'>
# list index out of range
# Processing Record 139 of set1 | Claudio Miranda
# <class 'IndexError'>
# list index out of range
# Processing Record 140 of set1 | Wally Pfister
# <class 'IndexError'>
# list index out of range
# Processing Record 141 of set1 | Chris Menges and Roger Deakins
# <class 'IndexError'>
# list index out of range
# Processing Record 142 of set1 | Anthony Dod Mantle
# <class 'IndexError'>
# list index out of range
# Processing Record 143 of set1 | Catherine Martin
# <class 'IndexError'>
# list index out of range
# Processing Record 144 of set1 | Jacqueline West
# <class 'IndexError'>
# list index out of range
# Processing Record 145 of set1 | Michael O'Connor
# <class 'IndexError'>
# list index out of range
# Processing Record 146 of set1 | Danny Glicker
# <class 'IndexError'>
# list index out of range
# Processing Record 147 of set1 | Albert Wolsky
# <class 'IndexError'>
# list index out of range
# Processing Record 148 of set1 | David Fincher
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=David%20Fincher
# Processing Record 149 of set1 | Ron Howard
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Ron%20Howard
# Processing Record 150 of set1 | Gus Van Sant
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Gus%20Van%20Sant
# Processing Record 151 of set1 | Stephen Daldry
# <class 'IndexError'>
# list index out of range
# Processing Record 152 of set1 | Danny Boyle
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Danny%20Boyle
# Processing Record 153 of set1 | Ellen Kuras and Thavisouk Phrasavath
# <class 'IndexError'>
# list index out of range
# Processing Record 154 of set1 | Werner Herzog and Henry Kaiser
# <class 'IndexError'>
# list index out of range
# Processing Record 155 of set1 | Scott Hamilton Kennedy
# <class 'IndexError'>
# list index out of range
# Processing Record 156 of set1 | James Marsh and Simon Chinn
# <class 'IndexError'>
# list index out of range
# Processing Record 157 of set1 | Tia Lessin and Carl Deal
# <class 'IndexError'>
# list index out of range
# Processing Record 158 of set1 | Steven Okazaki
# <class 'IndexError'>
# list index out of range
# Processing Record 159 of set1 | Irene Taylor Brodsky and Tom Grant
# <class 'IndexError'>
# list index out of range
# Processing Record 160 of set1 | Megan Mylan
# <class 'IndexError'>
# list index out of range
# Processing Record 161 of set1 | Adam Pertofsky and Margaret Hyde
# <class 'IndexError'>
# list index out of range
# ...
# Processing Record 12 of set1 | Written by Damien Chazelle
# <class 'IndexError'>
# list index out of range
# Processing Record 13 of set1 | Written by Alejandro G. Iñárritu, Nicolás Giacobone, Alexander Dinelaris, Jr. & Armando Bo
# <class 'IndexError'>
# list index out of range
# Processing Record 14 of set1 | Written by Richard Linklater
# <class 'IndexError'>
# list index out of range
# Processing Record 15 of set1 | Written by E. Max Frye and Dan Futterman
# <class 'IndexError'>
# list index out of range
# Processing Record 16 of set1 | Screenplay by Wes Anderson; Story by Wes Anderson & Hugo Guinness
# <class 'IndexError'>
# list index out of range
# Processing Record 17 of set1 | Written by Dan Gilroy
# <class 'IndexError'>
# list index out of range
# Processing Record 18 of set1 | nan
# <class 'TypeError'>
# must be str, not float
# Processing Record 19 of set1 | nan
# <class 'TypeError'>
# must be str, not float
# Processing Record 20 of set1 | nan
# <class 'TypeError'>
# must be str, not float
# Processing Record 21 of set1 | nan
# <class 'TypeError'>
# must be str, not float
# Processing Record 22 of set1 | nan
# <class 'TypeError'>
# must be str, not float
# Processing Record 23 of set1 | nan
# <class 'TypeError'>
# must be str, not float
# Processing Record 24 of set1 | Trumbo
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Trumbo
# Processing Record 25 of set1 | The Martian
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=The%20Martian
# Processing Record 26 of set1 | The Revenant
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=The%20Revenant
# Processing Record 27 of set1 | Steve Jobs
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Steve%20Jobs
# Processing Record 28 of set1 | The Danish Girl
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=The%20Danish%20Girl
# Processing Record 29 of set1 | The Big Short
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=The%20Big%20Short
# Processing Record 30 of set1 | The Revenant
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=The%20Revenant
# Processing Record 31 of set1 | Spotlight
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Spotlight
# Processing Record 32 of set1 | Bridge of Spies
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Bridge%20of%20Spies
# Processing Record 33 of set1 | Creed
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Creed
# Processing Record 34 of set1 | Carol
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Carol
# Processing Record 35 of set1 | Room
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Room
# Processing Record 36 of set1 | Joy
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Joy
# Processing Record 37 of set1 | 45 Years
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=45%20Years
# Processing Record 38 of set1 | Brooklyn
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Brooklyn
# Processing Record 39 of set1 | The Hateful Eight
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=The%20Hateful%20Eight
# Processing Record 40 of set1 | Carol
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Carol
# Processing Record 41 of set1 | Spotlight
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Spotlight
# Processing Record 42 of set1 | The Danish Girl
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=The%20Danish%20Girl
# Processing Record 43 of set1 | Steve Jobs
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Steve%20Jobs
# Processing Record 44 of set1 | Charlie Kaufman, Duke Johnson and Rosa Tran
# <class 'IndexError'>
# list index out of range
# Processing Record 45 of set1 | Alê Abreu
# <class 'IndexError'>
# list index out of range
# Processing Record 46 of set1 | Pete Docter and Jonas Rivera
# <class 'IndexError'>
# list index out of range
# Processing Record 47 of set1 | Mark Burton and Richard Starzak
# <class 'KeyError'>
# 'results'
# Processing Record 48 of set1 | Hiromasa Yonebayashi and Yoshiaki Nishimura
# <class 'IndexError'>
# list index out of range
# Processing Record 49 of set1 | Ed Lachman
# <class 'IndexError'>
# list index out of range
# Processing Record 50 of set1 | Robert Richardson
# <class 'IndexError'>
# list index out of range
# Processing Record 51 of set1 | John Seale
# <class 'IndexError'>
# list index out of range
# Processing Record 52 of set1 | Emmanuel Lubezki
# <class 'IndexError'>
# list index out of range
# Processing Record 53 of set1 | Roger Deakins
# <class 'IndexError'>
# list index out of range
# Processing Record 54 of set1 | Sandy Powell
# <class 'IndexError'>
# list index out of range
# Processing Record 55 of set1 | Sandy Powell
# <class 'IndexError'>
# list index out of range
# Processing Record 56 of set1 | Paco Delgado
# <class 'IndexError'>
# list index out of range
# Processing Record 57 of set1 | Jenny Beavan
# <class 'IndexError'>
# list index out of range
# Processing Record 58 of set1 | Jacqueline West
# <class 'IndexError'>
# list index out of range
# Processing Record 59 of set1 | Adam McKay
# <class 'IndexError'>
# list index out of range
# Processing Record 60 of set1 | George Miller
# <class 'IndexError'>
# list index out of range
# Processing Record 61 of set1 | Alejandro G. Iñárritu
# <class 'IndexError'>
# list index out of range
# Processing Record 62 of set1 | Lenny Abrahamson
# <class 'IndexError'>
# list index out of range
# Processing Record 63 of set1 | Tom McCarthy
# <class 'IndexError'>
# list index out of range
# Processing Record 64 of set1 | Asif Kapadia and James Gay-Rees
# <class 'IndexError'>
# list index out of range
# Processing Record 65 of set1 | Matthew Heineman and Tom Yellin
# <class 'IndexError'>
# list index out of range
# Processing Record 66 of set1 | Joshua Oppenheimer and Signe Byrge Sørensen
# <class 'IndexError'>
# list index out of range
# Processing Record 67 of set1 | Liz Garbus, Amy Hobby and Justin Wilkes
# <class 'IndexError'>
# list index out of range
# Processing Record 68 of set1 | Evgeny Afineevsky and Den Tolmor
# <class 'IndexError'>
# list index out of range
# Processing Record 69 of set1 | David Darg and Bryn Mooser
# <class 'IndexError'>
# list index out of range
# Processing Record 70 of set1 | Courtney Marsh and Jerry Franck
# <class 'IndexError'>
# list index out of range
# Processing Record 71 of set1 | Adam Benzine
# <class 'IndexError'>
# list index out of range
# Processing Record 72 of set1 | Sharmeen Obaid-Chinoy
# <class 'IndexError'>
# list index out of range
# Processing Record 73 of set1 | Dee Hibbert-Jones and Nomi Talisman
# <class 'IndexError'>
# list index out of range
# Processing Record 74 of set1 | Hank Corwin
# <class 'IndexError'>
# list index out of range
# Processing Record 75 of set1 | Margaret Sixel
# <class 'IndexError'>
# list index out of range
# Processing Record 76 of set1 | Stephen Mirrione
# <class 'IndexError'>
# list index out of range
# Processing Record 77 of set1 | Tom McArdle
# <class 'IndexError'>
# list index out of range
# Processing Record 78 of set1 | Maryann Brandon and Mary Jo Markey
# <class 'IndexError'>
# list index out of range
# Processing Record 79 of set1 | Colombia
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Colombia
# Processing Record 80 of set1 | France
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=France
# Processing Record 81 of set1 | Hungary
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Hungary
# Processing Record 82 of set1 | Jordan
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Jordan
# Processing Record 83 of set1 | Denmark
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Denmark
# Processing Record 84 of set1 | Lesley Vanderwalt, Elka Wardega and Damian Martin
# <class 'IndexError'>
# list index out of range
# Processing Record 85 of set1 | Love Larson and Eva von Bahr
# <class 'IndexError'>
# list index out of range
# Processing Record 86 of set1 | Siân Grigg, Duncan Jarman and Robert Pandini
# <class 'IndexError'>
# list index out of range
# Processing Record 87 of set1 | Thomas Newman
# <class 'IndexError'>
# list index out of range
# Processing Record 88 of set1 | Carter Burwell
# <class 'IndexError'>
# list index out of range
# Processing Record 89 of set1 | Ennio Morricone
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Ennio%20Morricone
# Processing Record 90 of set1 | Jóhann Jóhannsson
# <class 'IndexError'>
# list index out of range
# Processing Record 91 of set1 | John Williams
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=John%20Williams
# Processing Record 92 of set1 | Music and Lyric by The Weeknd, Ahmad Balshe, Jason Quenneville and Stephan Moccio
# <class 'IndexError'>
# list index out of range
# Processing Record 93 of set1 | Music by J. Ralph; Lyric by Anohni
# <class 'IndexError'>
# list index out of range
# Processing Record 94 of set1 | Music and Lyric by David Lang
# <class 'IndexError'>
# list index out of range
# Processing Record 95 of set1 | Music and Lyric by Diane Warren and Lady Gaga
# <class 'IndexError'>
# list index out of range
# Processing Record 96 of set1 | Music and Lyric by Jimmy Napes and Sam Smith
# <class 'IndexError'>
# list index out of range
# Processing Record 97 of set1 | Brad Pitt, Dede Gardner and Jeremy Kleiner, Producers
# <class 'IndexError'>
# list index out of range
# Processing Record 98 of set1 | Steven Spielberg, Marc Platt and Kristie Macosko Krieger, Producers
# <class 'IndexError'>
# list index out of range
# Processing Record 99 of set1 | Finola Dwyer and Amanda Posey, Producers
# <class 'IndexError'>
# list index out of range
# Processing Record 100 of set1 | Doug Mitchell and George Miller, Producers
# <class 'IndexError'>
# list index out of range
# Processing Record 101 of set1 | Simon Kinberg, Ridley Scott, Michael Schaefer and Mark Huffam, Producers
# <class 'IndexError'>
# list index out of range
# Processing Record 102 of set1 | Arnon Milchan, Steve Golin, Alejandro G. Iñárritu, Mary Parent and Keith Redmon, Producers
# <class 'IndexError'>
# list index out of range
# Processing Record 103 of set1 | Ed Guiney, Producer
# <class 'IndexError'>
# list index out of range
# Processing Record 104 of set1 | Michael Sugar, Steve Golin, Nicole Rocklin and Blye Pagon Faust, Producers
# <class 'IndexError'>
# list index out of range
# Processing Record 105 of set1 | Production Design: Adam Stockhausen; Set Decoration: Rena DeAngelo and Bernhard Henrich
# <class 'IndexError'>
# list index out of range
# Processing Record 106 of set1 | Production Design: Eve Stewart; Set Decoration: Michael Standish
# <class 'IndexError'>
# list index out of range
# Processing Record 107 of set1 | Production Design: Colin Gibson; Set Decoration: Lisa Thompson
# <class 'IndexError'>
# list index out of range
# Processing Record 108 of set1 | Production Design: Arthur Max; Set Decoration: Celia Bobak
# <class 'IndexError'>
# list index out of range
# Processing Record 109 of set1 | Production Design: Jack Fisk; Set Decoration: Hamish Purdy
# <class 'IndexError'>
# list index out of range
# Processing Record 110 of set1 | Gabriel Osorio and Pato Escala
# <class 'IndexError'>
# list index out of range
# Processing Record 111 of set1 | Richard Williams and Imogen Sutton
# <class 'IndexError'>
# list index out of range
# Processing Record 112 of set1 | Sanjay Patel and Nicole Grindle
# <class 'IndexError'>
# list index out of range
# Processing Record 113 of set1 | Konstantin Bronzit
# <class 'IndexError'>
# list index out of range
# Processing Record 114 of set1 | Don Hertzfeldt
# https://api.themoviedb.org/3/search/movie?api_key=98e159931ae83a9fde8ba0f8c795951d&query=Don%20Hertzfeldt
# Processing Record 115 of set1 | Basil Khalil and Eric Dupont
# <class 'IndexError'>
# list index out of range
# Processing Record 116 of set1 | Henry Hughes
# <class 'IndexError'>
# list index out of range
# Processing Record 117 of set1 | Patrick Vollrath
# <class 'IndexError'>
# list index out of range
# Processing Record 118 of set1 | Jamie Donoughue
# <class 'IndexError'>
# list index out of range
# Processing Record 119 of set1 | Benjamin Cleary and Serena Armitage
# <class 'IndexError'>
# list index out of range
# Processing Record 120 of set1 | Mark Mangini and David White
# <class 'IndexError'>
# list index out of range
# Processing Record 121 of set1 | Oliver Tarney
# <class 'IndexError'>
# list index out of range
# Processing Record 122 of set1 | Martin Hernandez and Lon Bender
# <class 'IndexError'>
# list index out of range
# Processing Record 123 of set1 | Alan Robert Murray
# <class 'IndexError'>
# list index out of range
# Processing Record 124 of set1 | Matthew Wood and David Acord
# <class 'IndexError'>
# list index out of range
# Processing Record 125 of set1 | Andy Nelson, Gary Rydstrom and Drew Kunin
# <class 'IndexError'>
# list index out of range
# Processing Record 126 of set1 | Chris Jenkins, Gregg Rudloff and Ben Osmo
# <class 'IndexError'>
# list index out of range
# Processing Record 127 of set1 | Paul Massey, Mark Taylor and Mac Ruth
# <class 'IndexError'>
# list index out of range
# Processing Record 128 of set1 | Jon Taylor, Frank A. Montaño, Randy Thom and Chris Duesterdiek
# <class 'IndexError'>
# list index out of range
# Processing Record 129 of set1 | Andy Nelson, Christopher Scarabosio and Stuart Wilson
# <class 'IndexError'>
# list index out of range
# Processing Record 130 of set1 | Andrew Whitehurst, Paul Norris, Mark Ardington and Sara Bennett
# <class 'IndexError'>
# list index out of range
# Processing Record 131 of set1 | Andrew Jackson, Tom Wood, Dan Oliver and Andy Williams
# <class 'IndexError'>
# list index out of range
# Processing Record 132 of set1 | Richard Stammers, Anders Langlands, Chris Lawrence and Steven Warner
# <class 'IndexError'>
# list index out of range
# Processing Record 133 of set1 | Rich McBride, Matthew Shumway, Jason Smith and Cameron Waldbauer
# <class 'IndexError'>
# list index out of range
# Processing Record 134 of set1 | Roger Guyett, Patrick Tubach, Neal Scanlan and Chris Corbould
# <class 'IndexError'>
# list index out of range
# Processing Record 135 of set1 | Screenplay by Charles Randolph and Adam McKay
# <class 'IndexError'>
# list index out of range
# Processing Record 136 of set1 | Screenplay by Nick Hornby
# <class 'IndexError'>
# list index out of range
# Processing Record 137 of set1 | Screenplay by Phyllis Nagy
# <class 'IndexError'>
# list index out of range
# Processing Record 138 of set1 | Screenplay by Drew Goddard
# <class 'IndexError'>
# list index out of range
# Processing Record 139 of set1 | Screenplay by Emma Donoghue
# <class 'IndexError'>
# list index out of range
# Processing Record 140 of set1 | Written by Matt Charman and Ethan Coen & Joel Coen
# <class 'IndexError'>
# list index out of range
# Processing Record 141 of set1 | Written by Alex Garland
# <class 'IndexError'>
# list index out of range
# Processing Record 142 of set1 | Screenplay by Pete Docter, Meg LeFauve, Josh Cooley; Original Story by Pete Docter, Ronnie del Carmen
# <class 'IndexError'>
# list index out of range
# Processing Record 143 of set1 | Written by Josh Singer & Tom McCarthy
# <class 'IndexError'>
# list index out of range
# Processing Record 144 of set1 | Screenplay by Jonathan Herman and Andrea Berloff; Story by S. Leigh Savidge & Alan Wenkus and Andrea Berloff
# <class 'IndexError'>
# list index out of range
# Processing Record 145 of set1 | nan
# <class 'TypeError'>
# must be str, not float
# Processing Record 146 of set1 | nan
# <class 'TypeError'>
# must be str, not float
# Processing Record 147 of set1 | nan
# <class 'TypeError'>
# must be str, not float
# ------------------------------
#  End of Data Retrieval
# ------------------------------
# 1009

# %%
print(id_list)
print(len(id_list))
# Out:
# [398, 398, 168672, 142, 69, 3291, 231, 1640, 921, 142, 59, 10773, 546, 234200, 9701, 69, 1444, 398, 9701, 1985, 142, 40581, 548662, 403011, 345115, 523773, 358881, 434166, 426632, 352748, 352748, 51227, 1372, 7859, 13771, 1402, 1523, 773, 1440, 1372, 1125, 1422, 219, 1259, 1165, 350, 1164, 1259, 773, 1125, 1164, 397406, 55676, 127598, 479394, 380830, 434166, 15279, 409070, 232044, 554526, 4566, 7345, 13885, 6973, 2252, 4512, 6977, 6538, 5915, 4566, 4517, 1919, 1407, 8272, 7326, 3902, 4982, 4347, 4771, 4566, 455359, 374317, 413362, 397255, 198802, 496, 657, 12473, 11499, 10139, 4922, 12163, 10139, 7446, 14359, 155, 4148, 14976, 3580, 10183, 14359, 8055, 14359, 5038, 14359, 4922, 12163, 395973, 275838, 1665, 1272, 25842, 434166, 358881, 62459, 554526, 367151, 482346, 51227, 25196, 22947, 34653, 22954, 12162, 22954, 28089, 36811, 7980, 16869, 22881, 36811, 24684, 25793, 24803, 10197, 22947, 25196, 22947, 25793, 536087, 102041, 199951, 132363, 413362, 565688, 358881, 34036, 434166, 458853, 554526, 435011, 45958, 44264, 37799, 45269, 44115, 45317, 39013, 23168, 39781, 45269, 39781, 27585, 39013, 44214, 46705, 45317, 45269, 45317, 44629, 395973, 15279, 409070, 380830, 435011, 554526, 482346, 51227, 55720, 65057, 74643, 49517, 60308, 75900, 60308, 59440, 55347, 64685, 73873, 50014, 65754, 71688, 75900, 74643, 50014, 55721, 73873, 50014, 12176, 44896, 381334, 55676, 81167, 221889, 708, 13646, 413362, 198802, 409070, 135136, 352748, 352748, 82693, 72976, 82695, 68722, 87502, 68734, 72976, 68718, 97630, 82693, 86837, 84175, 80278, 68722, 72976, 82695, 113947, 82693, 3933, 308332, 354937, 548662, 345115, 397255, 285554, 372866, 479394, 409070, 554526, 352748, 313828, 253254, 168672, 129670, 106646, 76203, 152532, 109424, 168672, 76203, 106646, 152532, 168672, 160588, 49047, 205220, 152737, 160588, 168672, 76203, 152737, 129670, 148975, 13646, 523773, 479394, 297036, 225360, 352748, 554526, 87492, 190859, 205596, 194662, 266856, 205587, 85350, 194662, 87492, 244786, 221902, 266856, 284293, 210577, 228970, 85350, 228970, 205596, 194662, 224141, 381334, 290304, 536087, 198802, 657, 253080, 536484, 34036, 554526, 554526, 435011, 51227, 294016, 286217, 281957, 321697, 306819, 318846, 281957, 314365, 296098, 312221, 258480, 264644, 274479, 311291, 167073, 273248, 258480, 314365, 306819, 321697, 14028, 358881, 53189, 52370, 479394, 171644, 352748, 491953]
# 333

# %%
url2 = "https://api.themoviedb.org/3/movie/"

api_key = "api_key=98e159931ae83a9fde8ba0f8c795951d"
payload = "{}"

# %%
movies_df = pd.DataFrame(columns = ["Movie", "Release Date","Budget", "Revenue", "Genres"])
call_count = 1
sets = 1
index = 0
movies_df.head()
# Out:
# Empty DataFrame
# Columns: [Movie, Release Date, Budget, Revenue, Genres]
# Index: []

# %%
for x in id_list:
    try:
        print(f'Processing Record {call_count} of set{sets} | {x}')
        print(url2)
        response = requests.request("GET", url2 + str(x) + "?&" + api_key, data=payload)
        json_data = response.json()
        movies_df.set_value(index, "Movie", json_data['original_title'])
        movies_df.set_value(index, "Release Date", json_data['release_date'])
        movies_df.set_value(index, "Revenue", json_data['revenue'])
        movies_df.set_value(index, "Budget", json_data['budget'])
        movies_df.set_value(index,"Genres", (json_data['genres'][0])['name'])
        index = index + 1
    except Exception as e:
        print(type(e))
        print(str(e))
    call_count = call_count + 1
    if call_count == 240:
        call_count1 = 1
        time.sleep(60)
# Out:
# Processing Record 1 of set1 | 398
# https://api.themoviedb.org/3/movie/
# c:\users\jorge\anaconda3\envs\myenvironment\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys
# c:\users\jorge\anaconda3\envs\myenvironment\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# c:\users\jorge\anaconda3\envs\myenvironment\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if __name__ == '__main__':
# c:\users\jorge\anaconda3\envs\myenvironment\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# c:\users\jorge\anaconda3\envs\myenvironment\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # This is added back by InteractiveShellApp.init_path()
# Processing Record 2 of set1 | 398
# https://api.themoviedb.org/3/movie/
# Processing Record 3 of set1 | 168672
# https://api.themoviedb.org/3/movie/
# Processing Record 4 of set1 | 142
# https://api.themoviedb.org/3/movie/
# Processing Record 5 of set1 | 69
# https://api.themoviedb.org/3/movie/
# Processing Record 6 of set1 | 3291
# https://api.themoviedb.org/3/movie/
# Processing Record 7 of set1 | 231
# https://api.themoviedb.org/3/movie/
# Processing Record 8 of set1 | 1640
# https://api.themoviedb.org/3/movie/
# Processing Record 9 of set1 | 921
# https://api.themoviedb.org/3/movie/
# Processing Record 10 of set1 | 142
# https://api.themoviedb.org/3/movie/
# Processing Record 11 of set1 | 59
# https://api.themoviedb.org/3/movie/
# Processing Record 12 of set1 | 10773
# https://api.themoviedb.org/3/movie/
# Processing Record 13 of set1 | 546
# https://api.themoviedb.org/3/movie/
# Processing Record 14 of set1 | 234200
# https://api.themoviedb.org/3/movie/
# Processing Record 15 of set1 | 9701
# https://api.themoviedb.org/3/movie/
# Processing Record 16 of set1 | 69
# https://api.themoviedb.org/3/movie/
# Processing Record 17 of set1 | 1444
# https://api.themoviedb.org/3/movie/
# Processing Record 18 of set1 | 398
# https://api.themoviedb.org/3/movie/
# Processing Record 19 of set1 | 9701
# https://api.themoviedb.org/3/movie/
# Processing Record 20 of set1 | 1985
# https://api.themoviedb.org/3/movie/
# Processing Record 21 of set1 | 142
# https://api.themoviedb.org/3/movie/
# Processing Record 22 of set1 | 40581
# https://api.themoviedb.org/3/movie/
# Processing Record 23 of set1 | 548662
# https://api.themoviedb.org/3/movie/
# Processing Record 24 of set1 | 403011
# https://api.themoviedb.org/3/movie/
# Processing Record 25 of set1 | 345115
# https://api.themoviedb.org/3/movie/
# Processing Record 26 of set1 | 523773
# https://api.themoviedb.org/3/movie/
# Processing Record 27 of set1 | 358881
# https://api.themoviedb.org/3/movie/
# Processing Record 28 of set1 | 434166
# https://api.themoviedb.org/3/movie/
# Processing Record 29 of set1 | 426632
# https://api.themoviedb.org/3/movie/
# Processing Record 30 of set1 | 352748
# https://api.themoviedb.org/3/movie/
# Processing Record 31 of set1 | 352748
# https://api.themoviedb.org/3/movie/
# Processing Record 32 of set1 | 51227
# https://api.themoviedb.org/3/movie/
# Processing Record 33 of set1 | 1372
# https://api.themoviedb.org/3/movie/
# Processing Record 34 of set1 | 7859
# https://api.themoviedb.org/3/movie/
# Processing Record 35 of set1 | 13771
# https://api.themoviedb.org/3/movie/
# Processing Record 36 of set1 | 1402
# https://api.themoviedb.org/3/movie/
# Processing Record 37 of set1 | 1523
# https://api.themoviedb.org/3/movie/
# Processing Record 38 of set1 | 773
# https://api.themoviedb.org/3/movie/
# Processing Record 39 of set1 | 1440
# https://api.themoviedb.org/3/movie/
# Processing Record 40 of set1 | 1372
# https://api.themoviedb.org/3/movie/
# Processing Record 41 of set1 | 1125
# https://api.themoviedb.org/3/movie/
# Processing Record 42 of set1 | 1422
# https://api.themoviedb.org/3/movie/
# Processing Record 43 of set1 | 219
# https://api.themoviedb.org/3/movie/
# Processing Record 44 of set1 | 1259
# https://api.themoviedb.org/3/movie/
# Processing Record 45 of set1 | 1165
# https://api.themoviedb.org/3/movie/
# Processing Record 46 of set1 | 350
# https://api.themoviedb.org/3/movie/
# Processing Record 47 of set1 | 1164
# https://api.themoviedb.org/3/movie/
# Processing Record 48 of set1 | 1259
# https://api.themoviedb.org/3/movie/
# Processing Record 49 of set1 | 773
# https://api.themoviedb.org/3/movie/
# Processing Record 50 of set1 | 1125
# https://api.themoviedb.org/3/movie/
# Processing Record 51 of set1 | 1164
# https://api.themoviedb.org/3/movie/
# Processing Record 52 of set1 | 397406
# https://api.themoviedb.org/3/movie/
# Processing Record 53 of set1 | 55676
# https://api.themoviedb.org/3/movie/
# Processing Record 54 of set1 | 127598
# https://api.themoviedb.org/3/movie/
# <class 'IndexError'>
# list index out of range
# Processing Record 55 of set1 | 479394
# https://api.themoviedb.org/3/movie/
# Processing Record 56 of set1 | 380830
# https://api.themoviedb.org/3/movie/
# Processing Record 57 of set1 | 434166
# https://api.themoviedb.org/3/movie/
# Processing Record 58 of set1 | 15279
# https://api.themoviedb.org/3/movie/
# <class 'IndexError'>
# list index out of range
# Processing Record 59 of set1 | 409070
# https://api.themoviedb.org/3/movie/
# <class 'IndexError'>
# list index out of range
# Processing Record 60 of set1 | 232044
# https://api.themoviedb.org/3/movie/
# Processing Record 61 of set1 | 554526
# https://api.themoviedb.org/3/movie/
# Processing Record 62 of set1 | 4566
# https://api.themoviedb.org/3/movie/
# Processing Record 63 of set1 | 7345
# https://api.themoviedb.org/3/movie/
# Processing Record 64 of set1 | 13885
# https://api.themoviedb.org/3/movie/
# Processing Record 65 of set1 | 6973
# https://api.themoviedb.org/3/movie/
# Processing Record 66 of set1 | 2252
# https://api.themoviedb.org/3/movie/
# Processing Record 67 of set1 | 4512
# https://api.themoviedb.org/3/movie/
# Processing Record 68 of set1 | 6977
# https://api.themoviedb.org/3/movie/
# Processing Record 69 of set1 | 6538
# https://api.themoviedb.org/3/movie/
# Processing Record 70 of set1 | 5915
# https://api.themoviedb.org/3/movie/
# Processing Record 71 of set1 | 4566
# https://api.themoviedb.org/3/movie/
# Processing Record 72 of set1 | 4517
# https://api.themoviedb.org/3/movie/
# Processing Record 73 of set1 | 1919
# https://api.themoviedb.org/3/movie/
# Processing Record 74 of set1 | 1407
# https://api.themoviedb.org/3/movie/
# Processing Record 75 of set1 | 8272
# https://api.themoviedb.org/3/movie/
# Processing Record 76 of set1 | 7326
# https://api.themoviedb.org/3/movie/
# Processing Record 77 of set1 | 3902
# https://api.themoviedb.org/3/movie/
# Processing Record 78 of set1 | 4982
# https://api.themoviedb.org/3/movie/
# Processing Record 79 of set1 | 4347
# https://api.themoviedb.org/3/movie/
# Processing Record 80 of set1 | 4771
# https://api.themoviedb.org/3/movie/
# Processing Record 81 of set1 | 4566
# https://api.themoviedb.org/3/movie/
# Processing Record 82 of set1 | 455359
# https://api.themoviedb.org/3/movie/
# Processing Record 83 of set1 | 374317
# https://api.themoviedb.org/3/movie/
# Processing Record 84 of set1 | 413362
# https://api.themoviedb.org/3/movie/
# Processing Record 85 of set1 | 397255
# https://api.themoviedb.org/3/movie/
# <class 'IndexError'>
# list index out of range
# Processing Record 86 of set1 | 198802
# https://api.themoviedb.org/3/movie/
# Processing Record 87 of set1 | 496
# https://api.themoviedb.org/3/movie/
# Processing Record 88 of set1 | 657
# https://api.themoviedb.org/3/movie/
# Processing Record 89 of set1 | 12473
# https://api.themoviedb.org/3/movie/
# Processing Record 90 of set1 | 11499
# https://api.themoviedb.org/3/movie/
# Processing Record 91 of set1 | 10139
# https://api.themoviedb.org/3/movie/
# Processing Record 92 of set1 | 4922
# https://api.themoviedb.org/3/movie/
# Processing Record 93 of set1 | 12163
# https://api.themoviedb.org/3/movie/
# Processing Record 94 of set1 | 10139
# https://api.themoviedb.org/3/movie/
# Processing Record 95 of set1 | 7446
# https://api.themoviedb.org/3/movie/
# Processing Record 96 of set1 | 14359
# https://api.themoviedb.org/3/movie/
# Processing Record 97 of set1 | 155
# https://api.themoviedb.org/3/movie/
# Processing Record 98 of set1 | 4148
# https://api.themoviedb.org/3/movie/
# Processing Record 99 of set1 | 14976
# https://api.themoviedb.org/3/movie/
# Processing Record 100 of set1 | 3580
# https://api.themoviedb.org/3/movie/
# Processing Record 101 of set1 | 10183
# https://api.themoviedb.org/3/movie/
# Processing Record 102 of set1 | 14359
# https://api.themoviedb.org/3/movie/
# Processing Record 103 of set1 | 8055
# https://api.themoviedb.org/3/movie/
# Processing Record 104 of set1 | 14359
# https://api.themoviedb.org/3/movie/
# Processing Record 105 of set1 | 5038
# https://api.themoviedb.org/3/movie/
# Processing Record 106 of set1 | 14359
# https://api.themoviedb.org/3/movie/
# Processing Record 107 of set1 | 4922
# https://api.themoviedb.org/3/movie/
# Processing Record 108 of set1 | 12163
# https://api.themoviedb.org/3/movie/
# Processing Record 109 of set1 | 395973
# https://api.themoviedb.org/3/movie/
# Processing Record 110 of set1 | 275838
# https://api.themoviedb.org/3/movie/
# <class 'IndexError'>
# list index out of range
# Processing Record 111 of set1 | 1665
# https://api.themoviedb.org/3/movie/
# Processing Record 112 of set1 | 1272
# https://api.themoviedb.org/3/movie/
# Processing Record 113 of set1 | 25842
# https://api.themoviedb.org/3/movie/
# Processing Record 114 of set1 | 434166
# https://api.themoviedb.org/3/movie/
# Processing Record 115 of set1 | 358881
# https://api.themoviedb.org/3/movie/
# Processing Record 116 of set1 | 62459
# https://api.themoviedb.org/3/movie/
# Processing Record 117 of set1 | 554526
# https://api.themoviedb.org/3/movie/
# Processing Record 118 of set1 | 367151
# https://api.themoviedb.org/3/movie/
# Processing Record 119 of set1 | 482346
# https://api.themoviedb.org/3/movie/
# Processing Record 120 of set1 | 51227
# https://api.themoviedb.org/3/movie/
# Processing Record 121 of set1 | 25196
# https://api.themoviedb.org/3/movie/
# Processing Record 122 of set1 | 22947
# https://api.themoviedb.org/3/movie/
# Processing Record 123 of set1 | 34653
# https://api.themoviedb.org/3/movie/
# Processing Record 124 of set1 | 22954
# https://api.themoviedb.org/3/movie/
# Processing Record 125 of set1 | 12162
# https://api.themoviedb.org/3/movie/
# Processing Record 126 of set1 | 22954
# https://api.themoviedb.org/3/movie/
# Processing Record 127 of set1 | 28089
# https://api.themoviedb.org/3/movie/
# Processing Record 128 of set1 | 36811
# https://api.themoviedb.org/3/movie/
# Processing Record 129 of set1 | 7980
# https://api.themoviedb.org/3/movie/
# Processing Record 130 of set1 | 16869
# https://api.themoviedb.org/3/movie/
# Processing Record 131 of set1 | 22881
# https://api.themoviedb.org/3/movie/
# Processing Record 132 of set1 | 36811
# https://api.themoviedb.org/3/movie/
# Processing Record 133 of set1 | 24684
# https://api.themoviedb.org/3/movie/
# Processing Record 134 of set1 | 25793
# https://api.themoviedb.org/3/movie/
# Processing Record 135 of set1 | 24803
# https://api.themoviedb.org/3/movie/
# Processing Record 136 of set1 | 10197
# https://api.themoviedb.org/3/movie/
# Processing Record 137 of set1 | 22947
# https://api.themoviedb.org/3/movie/
# Processing Record 138 of set1 | 25196
# https://api.themoviedb.org/3/movie/
# Processing Record 139 of set1 | 22947
# https://api.themoviedb.org/3/movie/
# Processing Record 140 of set1 | 25793
# https://api.themoviedb.org/3/movie/
# Processing Record 141 of set1 | 536087
# https://api.themoviedb.org/3/movie/
# Processing Record 142 of set1 | 102041
# https://api.themoviedb.org/3/movie/
# Processing Record 143 of set1 | 199951
# https://api.themoviedb.org/3/movie/
# Processing Record 144 of set1 | 132363
# https://api.themoviedb.org/3/movie/
# Processing Record 145 of set1 | 413362
# https://api.themoviedb.org/3/movie/
# Processing Record 146 of set1 | 565688
# https://api.themoviedb.org/3/movie/
# Processing Record 147 of set1 | 358881
# https://api.themoviedb.org/3/movie/
# Processing Record 148 of set1 | 34036
# https://api.themoviedb.org/3/movie/
# Processing Record 149 of set1 | 434166
# https://api.themoviedb.org/3/movie/
# Processing Record 150 of set1 | 458853
# https://api.themoviedb.org/3/movie/
# <class 'IndexError'>
# list index out of range
# Processing Record 151 of set1 | 554526
# https://api.themoviedb.org/3/movie/
# Processing Record 152 of set1 | 435011
# https://api.themoviedb.org/3/movie/
# Processing Record 153 of set1 | 45958
# https://api.themoviedb.org/3/movie/
# Processing Record 154 of set1 | 44264
# https://api.themoviedb.org/3/movie/
# Processing Record 155 of set1 | 37799
# https://api.themoviedb.org/3/movie/
# Processing Record 156 of set1 | 45269
# https://api.themoviedb.org/3/movie/
# Processing Record 157 of set1 | 44115
# https://api.themoviedb.org/3/movie/
# Processing Record 158 of set1 | 45317
# https://api.themoviedb.org/3/movie/
# Processing Record 159 of set1 | 39013
# https://api.themoviedb.org/3/movie/
# Processing Record 160 of set1 | 23168
# https://api.themoviedb.org/3/movie/
# Processing Record 161 of set1 | 39781
# https://api.themoviedb.org/3/movie/
# Processing Record 162 of set1 | 45269
# https://api.themoviedb.org/3/movie/
# Processing Record 163 of set1 | 39781
# https://api.themoviedb.org/3/movie/
# Processing Record 164 of set1 | 27585
# https://api.themoviedb.org/3/movie/
# Processing Record 165 of set1 | 39013
# https://api.themoviedb.org/3/movie/
# Processing Record 166 of set1 | 44214
# https://api.themoviedb.org/3/movie/
# Processing Record 167 of set1 | 46705
# https://api.themoviedb.org/3/movie/
# Processing Record 168 of set1 | 45317
# https://api.themoviedb.org/3/movie/
# Processing Record 169 of set1 | 45269
# https://api.themoviedb.org/3/movie/
# Processing Record 170 of set1 | 45317
# https://api.themoviedb.org/3/movie/
# Processing Record 171 of set1 | 44629
# https://api.themoviedb.org/3/movie/
# Processing Record 172 of set1 | 395973
# https://api.themoviedb.org/3/movie/
# Processing Record 173 of set1 | 15279
# https://api.themoviedb.org/3/movie/
# <class 'IndexError'>
# list index out of range
# Processing Record 174 of set1 | 409070
# https://api.themoviedb.org/3/movie/
# <class 'IndexError'>
# list index out of range
# Processing Record 175 of set1 | 380830
# https://api.themoviedb.org/3/movie/
# Processing Record 176 of set1 | 435011
# https://api.themoviedb.org/3/movie/
# Processing Record 177 of set1 | 554526
# https://api.themoviedb.org/3/movie/
# Processing Record 178 of set1 | 482346
# https://api.themoviedb.org/3/movie/
# Processing Record 179 of set1 | 51227
# https://api.themoviedb.org/3/movie/
# Processing Record 180 of set1 | 55720
# https://api.themoviedb.org/3/movie/
# Processing Record 181 of set1 | 65057
# https://api.themoviedb.org/3/movie/
# Processing Record 182 of set1 | 74643
# https://api.themoviedb.org/3/movie/
# Processing Record 183 of set1 | 49517
# https://api.themoviedb.org/3/movie/
# Processing Record 184 of set1 | 60308
# https://api.themoviedb.org/3/movie/
# Processing Record 185 of set1 | 75900
# https://api.themoviedb.org/3/movie/
# Processing Record 186 of set1 | 60308
# https://api.themoviedb.org/3/movie/
# Processing Record 187 of set1 | 59440
# https://api.themoviedb.org/3/movie/
# Processing Record 188 of set1 | 55347
# https://api.themoviedb.org/3/movie/
# Processing Record 189 of set1 | 64685
# https://api.themoviedb.org/3/movie/
# Processing Record 190 of set1 | 73873
# https://api.themoviedb.org/3/movie/
# Processing Record 191 of set1 | 50014
# https://api.themoviedb.org/3/movie/
# Processing Record 192 of set1 | 65754
# https://api.themoviedb.org/3/movie/
# Processing Record 193 of set1 | 71688
# https://api.themoviedb.org/3/movie/
# Processing Record 194 of set1 | 75900
# https://api.themoviedb.org/3/movie/
# Processing Record 195 of set1 | 74643
# https://api.themoviedb.org/3/movie/
# Processing Record 196 of set1 | 50014
# https://api.themoviedb.org/3/movie/
# Processing Record 197 of set1 | 55721
# https://api.themoviedb.org/3/movie/
# Processing Record 198 of set1 | 73873
# https://api.themoviedb.org/3/movie/
# Processing Record 199 of set1 | 50014
# https://api.themoviedb.org/3/movie/
# Processing Record 200 of set1 | 12176
# https://api.themoviedb.org/3/movie/
# Processing Record 201 of set1 | 44896
# https://api.themoviedb.org/3/movie/
# Processing Record 202 of set1 | 381334
# https://api.themoviedb.org/3/movie/
# Processing Record 203 of set1 | 55676
# https://api.themoviedb.org/3/movie/
# Processing Record 204 of set1 | 81167
# https://api.themoviedb.org/3/movie/
# Processing Record 205 of set1 | 221889
# https://api.themoviedb.org/3/movie/
# Processing Record 206 of set1 | 708
# https://api.themoviedb.org/3/movie/
# Processing Record 207 of set1 | 13646
# https://api.themoviedb.org/3/movie/
# Processing Record 208 of set1 | 413362
# https://api.themoviedb.org/3/movie/
# Processing Record 209 of set1 | 198802
# https://api.themoviedb.org/3/movie/
# Processing Record 210 of set1 | 409070
# https://api.themoviedb.org/3/movie/
# <class 'IndexError'>
# list index out of range
# Processing Record 211 of set1 | 135136
# https://api.themoviedb.org/3/movie/
# <class 'IndexError'>
# list index out of range
# Processing Record 212 of set1 | 352748
# https://api.themoviedb.org/3/movie/
# Processing Record 213 of set1 | 352748
# https://api.themoviedb.org/3/movie/
# Processing Record 214 of set1 | 82693
# https://api.themoviedb.org/3/movie/
# Processing Record 215 of set1 | 72976
# https://api.themoviedb.org/3/movie/
# Processing Record 216 of set1 | 82695
# https://api.themoviedb.org/3/movie/
# Processing Record 217 of set1 | 68722
# https://api.themoviedb.org/3/movie/
# Processing Record 218 of set1 | 87502
# https://api.themoviedb.org/3/movie/
# Processing Record 219 of set1 | 68734
# https://api.themoviedb.org/3/movie/
# Processing Record 220 of set1 | 72976
# https://api.themoviedb.org/3/movie/
# Processing Record 221 of set1 | 68718
# https://api.themoviedb.org/3/movie/
# Processing Record 222 of set1 | 97630
# https://api.themoviedb.org/3/movie/
# Processing Record 223 of set1 | 82693
# https://api.themoviedb.org/3/movie/
# Processing Record 224 of set1 | 86837
# https://api.themoviedb.org/3/movie/
# Processing Record 225 of set1 | 84175
# https://api.themoviedb.org/3/movie/
# Processing Record 226 of set1 | 80278
# https://api.themoviedb.org/3/movie/
# Processing Record 227 of set1 | 68722
# https://api.themoviedb.org/3/movie/
# Processing Record 228 of set1 | 72976
# https://api.themoviedb.org/3/movie/
# Processing Record 229 of set1 | 82695
# https://api.themoviedb.org/3/movie/
# Processing Record 230 of set1 | 113947
# https://api.themoviedb.org/3/movie/
# Processing Record 231 of set1 | 82693
# https://api.themoviedb.org/3/movie/
# Processing Record 232 of set1 | 3933
# https://api.themoviedb.org/3/movie/
# Processing Record 233 of set1 | 308332
# https://api.themoviedb.org/3/movie/
# <class 'IndexError'>
# list index out of range
# Processing Record 234 of set1 | 354937
# https://api.themoviedb.org/3/movie/
# <class 'IndexError'>
# list index out of range
# Processing Record 235 of set1 | 548662
# https://api.themoviedb.org/3/movie/
# Processing Record 236 of set1 | 345115
# https://api.themoviedb.org/3/movie/
# Processing Record 237 of set1 | 397255
# https://api.themoviedb.org/3/movie/
# <class 'IndexError'>
# list index out of range
# Processing Record 238 of set1 | 285554
# https://api.themoviedb.org/3/movie/
# Processing Record 239 of set1 | 372866
# https://api.themoviedb.org/3/movie/
# <class 'IndexError'>
# list index out of range
# Processing Record 240 of set1 | 479394
# https://api.themoviedb.org/3/movie/
# Processing Record 241 of set1 | 409070
# https://api.themoviedb.org/3/movie/
# <class 'IndexError'>
# list index out of range
# Processing Record 242 of set1 | 554526
# https://api.themoviedb.org/3/movie/
# Processing Record 243 of set1 | 352748
# https://api.themoviedb.org/3/movie/
# Processing Record 244 of set1 | 313828
# https://api.themoviedb.org/3/movie/
# Processing Record 245 of set1 | 253254
# https://api.themoviedb.org/3/movie/
# Processing Record 246 of set1 | 168672
# https://api.themoviedb.org/3/movie/
# Processing Record 247 of set1 | 129670
# https://api.themoviedb.org/3/movie/
# Processing Record 248 of set1 | 106646
# https://api.themoviedb.org/3/movie/
# Processing Record 249 of set1 | 76203
# https://api.themoviedb.org/3/movie/
# Processing Record 250 of set1 | 152532
# https://api.themoviedb.org/3/movie/
# Processing Record 251 of set1 | 109424
# https://api.themoviedb.org/3/movie/
# Processing Record 252 of set1 | 168672
# https://api.themoviedb.org/3/movie/
# Processing Record 253 of set1 | 76203
# https://api.themoviedb.org/3/movie/
# Processing Record 254 of set1 | 106646
# https://api.themoviedb.org/3/movie/
# Processing Record 255 of set1 | 152532
# https://api.themoviedb.org/3/movie/
# Processing Record 256 of set1 | 168672
# https://api.themoviedb.org/3/movie/
# Processing Record 257 of set1 | 160588
# https://api.themoviedb.org/3/movie/
# Processing Record 258 of set1 | 49047
# https://api.themoviedb.org/3/movie/
# Processing Record 259 of set1 | 205220
# https://api.themoviedb.org/3/movie/
# Processing Record 260 of set1 | 152737
# https://api.themoviedb.org/3/movie/
# Processing Record 261 of set1 | 160588
# https://api.themoviedb.org/3/movie/
# Processing Record 262 of set1 | 168672
# https://api.themoviedb.org/3/movie/
# Processing Record 263 of set1 | 76203
# https://api.themoviedb.org/3/movie/
# Processing Record 264 of set1 | 152737
# https://api.themoviedb.org/3/movie/
# Processing Record 265 of set1 | 129670
# https://api.themoviedb.org/3/movie/
# Processing Record 266 of set1 | 148975
# https://api.themoviedb.org/3/movie/
# Processing Record 267 of set1 | 13646
# https://api.themoviedb.org/3/movie/
# Processing Record 268 of set1 | 523773
# https://api.themoviedb.org/3/movie/
# Processing Record 269 of set1 | 479394
# https://api.themoviedb.org/3/movie/
# Processing Record 270 of set1 | 297036
# https://api.themoviedb.org/3/movie/
# Processing Record 271 of set1 | 225360
# https://api.themoviedb.org/3/movie/
# Processing Record 272 of set1 | 352748
# https://api.themoviedb.org/3/movie/
# Processing Record 273 of set1 | 554526
# https://api.themoviedb.org/3/movie/
# Processing Record 274 of set1 | 87492
# https://api.themoviedb.org/3/movie/
# Processing Record 275 of set1 | 190859
# https://api.themoviedb.org/3/movie/
# Processing Record 276 of set1 | 205596
# https://api.themoviedb.org/3/movie/
# Processing Record 277 of set1 | 194662
# https://api.themoviedb.org/3/movie/
# Processing Record 278 of set1 | 266856
# https://api.themoviedb.org/3/movie/
# Processing Record 279 of set1 | 205587
# https://api.themoviedb.org/3/movie/
# Processing Record 280 of set1 | 85350
# https://api.themoviedb.org/3/movie/
# Processing Record 281 of set1 | 194662
# https://api.themoviedb.org/3/movie/
# Processing Record 282 of set1 | 87492
# https://api.themoviedb.org/3/movie/
# Processing Record 283 of set1 | 244786
# https://api.themoviedb.org/3/movie/
# Processing Record 284 of set1 | 221902
# https://api.themoviedb.org/3/movie/
# Processing Record 285 of set1 | 266856
# https://api.themoviedb.org/3/movie/
# Processing Record 286 of set1 | 284293
# https://api.themoviedb.org/3/movie/
# Processing Record 287 of set1 | 210577
# https://api.themoviedb.org/3/movie/
# Processing Record 288 of set1 | 228970
# https://api.themoviedb.org/3/movie/
# Processing Record 289 of set1 | 85350
# https://api.themoviedb.org/3/movie/
# Processing Record 290 of set1 | 228970
# https://api.themoviedb.org/3/movie/
# Processing Record 291 of set1 | 205596
# https://api.themoviedb.org/3/movie/
# Processing Record 292 of set1 | 194662
# https://api.themoviedb.org/3/movie/
# Processing Record 293 of set1 | 224141
# https://api.themoviedb.org/3/movie/
# Processing Record 294 of set1 | 381334
# https://api.themoviedb.org/3/movie/
# Processing Record 295 of set1 | 290304
# https://api.themoviedb.org/3/movie/
# Processing Record 296 of set1 | 536087
# https://api.themoviedb.org/3/movie/
# Processing Record 297 of set1 | 198802
# https://api.themoviedb.org/3/movie/
# Processing Record 298 of set1 | 657
# https://api.themoviedb.org/3/movie/
# Processing Record 299 of set1 | 253080
# https://api.themoviedb.org/3/movie/
# Processing Record 300 of set1 | 536484
# https://api.themoviedb.org/3/movie/
# <class 'IndexError'>
# list index out of range
# Processing Record 301 of set1 | 34036
# https://api.themoviedb.org/3/movie/
# Processing Record 302 of set1 | 554526
# https://api.themoviedb.org/3/movie/
# Processing Record 303 of set1 | 554526
# https://api.themoviedb.org/3/movie/
# Processing Record 304 of set1 | 435011
# https://api.themoviedb.org/3/movie/
# Processing Record 305 of set1 | 51227
# https://api.themoviedb.org/3/movie/
# Processing Record 306 of set1 | 294016
# https://api.themoviedb.org/3/movie/
# Processing Record 307 of set1 | 286217
# https://api.themoviedb.org/3/movie/
# Processing Record 308 of set1 | 281957
# https://api.themoviedb.org/3/movie/
# Processing Record 309 of set1 | 321697
# https://api.themoviedb.org/3/movie/
# Processing Record 310 of set1 | 306819
# https://api.themoviedb.org/3/movie/
# Processing Record 311 of set1 | 318846
# https://api.themoviedb.org/3/movie/
# Processing Record 312 of set1 | 281957
# https://api.themoviedb.org/3/movie/
# Processing Record 313 of set1 | 314365
# https://api.themoviedb.org/3/movie/
# Processing Record 314 of set1 | 296098
# https://api.themoviedb.org/3/movie/
# Processing Record 315 of set1 | 312221
# https://api.themoviedb.org/3/movie/
# Processing Record 316 of set1 | 258480
# https://api.themoviedb.org/3/movie/
# Processing Record 317 of set1 | 264644
# https://api.themoviedb.org/3/movie/
# Processing Record 318 of set1 | 274479
# https://api.themoviedb.org/3/movie/
# Processing Record 319 of set1 | 311291
# https://api.themoviedb.org/3/movie/
# Processing Record 320 of set1 | 167073
# https://api.themoviedb.org/3/movie/
# Processing Record 321 of set1 | 273248
# https://api.themoviedb.org/3/movie/
# Processing Record 322 of set1 | 258480
# https://api.themoviedb.org/3/movie/
# Processing Record 323 of set1 | 314365
# https://api.themoviedb.org/3/movie/
# Processing Record 324 of set1 | 306819
# https://api.themoviedb.org/3/movie/
# Processing Record 325 of set1 | 321697
# https://api.themoviedb.org/3/movie/
# Processing Record 326 of set1 | 14028
# https://api.themoviedb.org/3/movie/
# Processing Record 327 of set1 | 358881
# https://api.themoviedb.org/3/movie/
# Processing Record 328 of set1 | 53189
# https://api.themoviedb.org/3/movie/
# Processing Record 329 of set1 | 52370
# https://api.themoviedb.org/3/movie/
# <class 'IndexError'>
# list index out of range
# Processing Record 330 of set1 | 479394
# https://api.themoviedb.org/3/movie/
# Processing Record 331 of set1 | 171644
# https://api.themoviedb.org/3/movie/
# <class 'IndexError'>
# list index out of range
# Processing Record 332 of set1 | 352748
# https://api.themoviedb.org/3/movie/
# Processing Record 333 of set1 | 491953
# https://api.themoviedb.org/3/movie/

# %%
movies_df.head()
# Out:
#                 Movie Release Date    Budget    Revenue Genres
# 0              Capote   2005-09-30   7000000   49084830  Crime
# 1              Capote   2005-09-30   7000000   49084830  Crime
# 2     American Hustle   2013-12-12  40000000  251171807  Drama
# 3  Brokeback Mountain   2005-09-10  14000000  178043761  Drama
# 4       Walk the Line   2005-09-13  28000000  186438883  Drama

# %%
movies_df.count
# Out:
# <bound method DataFrame.count of                                                  Movie Release Date  \
# 0                                               Capote   2005-09-30
# 1                                               Capote   2005-09-30
# 2                                      American Hustle   2013-12-12
# 3                                   Brokeback Mountain   2005-09-10
# 4                                        Walk the Line   2005-09-13
# 5                           Good Night, and Good Luck.   2005-09-16
# 6                                              Syriana   2005-11-23
# 7                                                Crash   2005-05-06
# 8                                       Cinderella Man   2005-06-02
# 9                                   Brokeback Mountain   2005-09-10
# 10                               A History of Violence   2005-09-23
# 11                              Mrs Henderson Presents   2005-09-08
# 12                                        Transamerica   2005-12-23
# 13                                               Pride   2014-09-12
# 14                                       North Country   2005-02-12
# 15                                       Walk the Line   2005-09-13
# 16                                             Junebug   2005-08-03
# 17                                              Capote   2005-09-30
# 18                                       North Country   2005-02-12
# 19                               The Constant Gardener   2005-08-31
# 20                                  Brokeback Mountain   2005-09-10
# 21                                          宮崎駿とジブリ美術館   2005-01-01
# 22   Lee Marvin and Angie Dickinson in Steve Reich'...   2005-01-01
# 23                                Being George Clooney   2016-02-06
# 24      Абдулладжан, или Посвящается Стивену Спилбергу   1991-01-01
# 25                                        Little Italy   2018-08-24
# 26                                      Made in France   2015-10-27
# 27                        Es war einmal in Deutschland   2017-04-06
# 28   Mumford & Sons Live from South Africa: Dust & ...   2016-11-05
# 29                         A John Williams Celebration   2015-06-15
# ..                                                 ...          ...
# 285               Bandes Originales: Alexandre Desplat   2018-02-12
# 286               Bandes Originales: Alexandre Desplat   2018-02-12
# 287                        Hans Zimmer: Live in Prague   2017-10-01
# 288                     King Richard And The Crusaders   1954-08-07
# 289                                             Trumbo   2015-10-27
# 290                                        The Martian   2015-09-30
# 291                                       The Revenant   2015-12-25
# 292                                         Steve Jobs   2015-10-09
# 293                                    The Danish Girl   2015-11-27
# 294                                      The Big Short   2015-12-11
# 295                                       The Revenant   2015-12-25
# 296                                          Spotlight   2015-11-06
# 297                                    Bridge of Spies   2015-10-15
# 298                                              Creed   2015-11-25
# 299                                              Carol   2015-11-20
# 300                                               Room   2015-10-16
# 301                                                Joy   2015-12-24
# 302                                           45 Years   2015-08-28
# 303                                           Brooklyn   2015-10-20
# 304                                  The Hateful Eight   2015-12-25
# 305                                              Carol   2015-11-20
# 306                                          Spotlight   2015-11-06
# 307                                    The Danish Girl   2015-11-27
# 308                                         Steve Jobs   2015-10-09
# 309                   Behind Enemy Lines III: Colombia   2009-01-06
# 310                                     Made in France   2015-10-27
# 311                                     Puskás Hungary   2009-03-12
# 312                                            Danmark   2017-10-01
# 313                        A John Williams Celebration   2015-06-15
# 314             The Simpsons: Don Hertzfeldt Couch Gag   2017-11-26
#
#         Budget    Revenue           Genres
# 0      7000000   49084830            Crime
# 1      7000000   49084830            Crime
# 2     40000000  251171807            Drama
# 3     14000000  178043761            Drama
# 4     28000000  186438883            Drama
# 5      7000000   54600000            Drama
# 6     50000000   93974620            Drama
# 7      6500000   98410061            Drama
# 8     88000000  108539911          Romance
# 9     14000000  178043761            Drama
# 10    32000000   60740827            Drama
# 11           0          0           Comedy
# 12     1000000   13350369            Drama
# 13           0    7523634            Drama
# 14    35000000   25224242            Drama
# 15    28000000  186438883            Drama
# 16     1000000          0           Comedy
# 17     7000000   49084830            Crime
# 18    35000000   25224242            Drama
# 19    25000000   82466670            Drama
# 20    14000000  178043761            Drama
# 21           0          0      Documentary
# 22           0          0            Music
# 23           0          0      Documentary
# 24           0          0           Comedy
# 25           0          0           Comedy
# 26           0          0            Drama
# 27           0          0           Comedy
# 28           0          0            Music
# 29           0          0            Music
# ..         ...        ...              ...
# 285          0          0      Documentary
# 286          0          0      Documentary
# 287          0          0            Music
# 288          0          0        Adventure
# 289   15000000    8235661            Drama
# 290  108000000  630161890            Drama
# 291  135000000  532950503          Western
# 292   30000000   34441873            Drama
# 293   15000000   64191523            Drama
# 294   28000000  133346506           Comedy
# 295  135000000  532950503          Western
# 296   20000000   88346473            Drama
# 297   40000000  165478348         Thriller
# 298   37000000  173567581            Drama
# 299          0   40272135          Romance
# 300    6000000   35401758            Drama
# 301   60000000  101134059            Drama
# 302          0    4250507            Drama
# 303   11000000   62076141            Drama
# 304   44000000  155760117            Crime
# 305          0   40272135          Romance
# 306   20000000   88346473            Drama
# 307   15000000   64191523            Drama
# 308   30000000   34441873            Drama
# 309          0          0              War
# 310          0          0            Drama
# 311          0          0      Documentary
# 312          0          0            Drama
# 313          0          0            Music
# 314          0          0  Science Fiction
#
# [315 rows x 5 columns]>

# %%
movies_df_clean2 = movies_df.drop_duplicates(keep= 'first')

# %%
movies_df_clean2.head(5)
# Out:
#                         Movie Release Date    Budget    Revenue Genres
# 0                      Capote   2005-09-30   7000000   49084830  Crime
# 2             American Hustle   2013-12-12  40000000  251171807  Drama
# 3          Brokeback Mountain   2005-09-10  14000000  178043761  Drama
# 4               Walk the Line   2005-09-13  28000000  186438883  Drama
# 5  Good Night, and Good Luck.   2005-09-16   7000000   54600000  Drama

# %%
movies_df_clean2.reset_index(inplace=True,drop=True)

# %%
movies_df_clean2.head()
# Out:
#                         Movie Release Date    Budget    Revenue Genres
# 0                      Capote   2005-09-30   7000000   49084830  Crime
# 1             American Hustle   2013-12-12  40000000  251171807  Drama
# 2          Brokeback Mountain   2005-09-10  14000000  178043761  Drama
# 3               Walk the Line   2005-09-13  28000000  186438883  Drama
# 4  Good Night, and Good Luck.   2005-09-16   7000000   54600000  Drama

# %%
print(len(movies_df_clean2))
# Out:
# 206

# %%
import csv

# %%
movies_df_clean2.to_csv('MovieQuery1_Clean')

# %%
movielist_1 = movies_df_clean2['Movie'].tolist()
print(movielist_1)
# Out:
# ['Capote', 'American Hustle', 'Brokeback Mountain', 'Walk the Line', 'Good Night, and Good Luck.', 'Syriana', 'Crash', 'Cinderella Man', 'A History of Violence', 'Mrs Henderson Presents', 'Transamerica', 'Pride', 'North Country', 'Junebug', 'The Constant Gardener', '宮崎駿とジブリ美術館', "Lee Marvin and Angie Dickinson in Steve Reich's 'Clapping Music'", 'Being George Clooney', 'Абдулладжан, или Посвящается Стивену Спилбергу', 'Little Italy', 'Made in France', 'Es war einmal in Deutschland', 'Mumford & Sons Live from South Africa: Dust & Thunder', 'A John Williams Celebration', 'King Richard And The Crusaders', 'Blood Diamond', 'Half Nelson', 'Venus', 'The Pursuit of Happyness', 'The Last King of Scotland', 'Little Miss Sunshine', 'Little Children', 'Dreamgirls', 'The Departed', 'Volver', 'Notes on a Scandal', 'The Queen', 'The Devil Wears Prada', 'Babel', 'Close Encounters with Vilmos Zsigmond', 'A Personal Journey with Martin Scorsese Through American Movies', 'Danmark', 'Good Luck Algeria', 'Philip Glass: Looking Glass', 'Bandes Originales: Alexandre Desplat', 'Michael Clayton', 'There Will Be Blood', 'Sweeney Todd: The Demon Barber of Fleet Street', 'In the Valley of Elah', 'Eastern Promises', 'The Assassination of Jesse James by the Coward Robert Ford', 'No Country for Old Men', "Charlie Wilson's War", 'Into the Wild', 'Elizabeth: The Golden Age', 'Away from Her', 'La Môme', 'The Savages', 'Juno', "I'm Not There.", 'American Gangster', 'Atonement', 'Gone Baby Gone', 'Julian Schnabel: A Private Portrait', 'A Christmas Eve Conversation With Quentin Tarantino & Paul Thomas Anderson', 'Roman J. Israel, Esq.', 'Ленин в Польше', 'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan', 'From Russia with Love', 'The Visitor', 'Frost/Nixon', 'Milk', 'The Curious Case of Benjamin Button', 'The Wrestler', 'Tropic Thunder', 'Doubt', 'The Dark Knight', 'Revolutionary Road', 'Rachel Getting Married', 'Changeling', 'Frozen River', 'The Reader', 'Vicky Cristina Barcelona', 'The Vice Guide to Film: David Fincher', 'Last Days', 'Sunshine', 'A Christmas Carol', 'iCarly: iGo to Japan', "Live From Lincoln Center: Danny Elfman's Music from the Films of Tim Burton", 'One Heart: The A.R. Rahman Concert Film', 'Crazy Heart', 'Up in the Air', 'A Single Man', 'Invictus', 'The Hurt Locker', 'The Messenger', 'The Last Station', 'The Lovely Bones', 'Inglourious Basterds', 'The Blind Side', 'An Education', 'Precious', 'Julie & Julia', 'Nine', 'Wes Anderson: From Above', 'Titanic: The Final Word with James Cameron', 'Quentin Tarantino: 20 Years of Filmmaking', 'The Butler', 'എന്\u200dറെ ഉമ്മാന്\u200dറെ പേര്', 'Imagining Argentina', 'Hans Zimmer: Live in Prague', 'Biutiful', 'True Grit', 'The Social Network', "The King's Speech", '127 Hours', 'The Fighter', "Winter's Bone", 'The Town', 'The Kids Are All Right', 'Rabbit Hole', 'Black Swan', 'Blue Valentine', 'Animal Kingdom', 'A Better Life', 'The Descendants', 'The Artist', 'Tinker Tailor Soldier Spy', 'Moneyball', 'My Week with Marilyn', 'Warrior', 'Beginners', 'Extremely Loud & Incredibly Close', 'Albert Nobbs', 'The Help', 'The Girl with the Dragon Tattoo', 'The Iron Lady', 'Bridesmaids', 'La corrupción de Chris Miller', 'Rango', 'Arnhem: The Battle for the Bridges - Part 1', 'Woody Allen: A Documentary', 'Rosy-Fingered Dawn: A Film on Terrence Malick', 'The Living Daylights', 'Aanrijding in Moscou', 'Silver Linings Playbook', 'Lincoln', 'Les Misérables', 'The Master', 'Flight', 'Argo', 'Django Unchained', 'Zero Dark Thirty', 'Amour', 'Beasts of the Southern Wild', 'Lo imposible', 'The Sessions', 'Corpse Bride', 'Νορβηγία', 'Pes', 'Before I Disappear', 'Nebraska', 'The Wolf of Wall Street', '12 Years a Slave', 'Dallas Buyers Club', 'Captain Phillips', 'Blue Jasmine', 'Gravity', 'Philomena', 'August: Osage County', 'Joe Louis Walker & The Bosstalkers in Concert', 'Intrusion: Cambodia', 'Palestine, Palestine', 'Foxcatcher', 'American Sniper', 'The Imitation Game', 'Birdman', 'The Th ...
