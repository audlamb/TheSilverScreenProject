# %%
import pandas as pd
import csv
import numpy as np
import matplotlib.pyplot as plt

# %%
film_data = pd.read_csv ("../TheSilverScreenProject/OMDB_TMDB_Merge/AllData_withOscarWins.csv")
film_data.head()
# Out:
#    Unnamed: 0                       Movie Release Date_x Release Date_y  \
# 0           0                      Capote     2005-09-30    03 Feb 2006
# 1           1             American Hustle     2013-12-12    20 Dec 2013
# 2           2          Brokeback Mountain     2005-09-10    13 Jan 2006
# 3           3               Walk the Line     2005-09-13    18 Nov 2005
# 4           4  Good Night, and Good Luck.     2005-09-16    04 Nov 2005
#
#        Budget      Revenue   Box Office Genres Rating  Runtime  Metascore  \
# 0   7000000.0   49084830.0   28337516.0  Crime      R    114.0       88.0
# 1  40000000.0  251171807.0   99165609.0  Drama      R    138.0       90.0
# 2  14000000.0  178043761.0   82970165.0  Drama      R    134.0       87.0
# 3  28000000.0  186438883.0  119317827.0  Drama  PG-13    136.0       72.0
# 4   7000000.0   54600000.0   31500000.0  Drama     PG     93.0       80.0
#
#    IMDb Rating          Awards           Production Company   wins  \
# ...

# %%
new_index_df = film_data.set_index("Win or Nominated")
nomination_df = new_index_df.loc['N']
nomination_df.head()
# Out:
#                   Unnamed: 0                       Movie Release Date_x  \
# Win or Nominated
# N                          1             American Hustle     2013-12-12
# N                          4  Good Night, and Good Luck.     2005-09-16
# N                          7              Cinderella Man     2005-06-02
# N                          8       A History of Violence     2005-09-23
# N                          9      Mrs Henderson Presents     2005-09-08
#
#                  Release Date_y      Budget      Revenue  Box Office   Genres  \
# Win or Nominated
# N                   20 Dec 2013  40000000.0  251171807.0  99165609.0    Drama
# N                   04 Nov 2005   7000000.0   54600000.0  31500000.0    Drama
# N                   03 Jun 2005  88000000.0  108539911.0  61600000.0  Romance
# N                   30 Sep 2005  32000000.0   60740827.0  31500000.0    Drama
# N                   17 Feb 2006         0.0          0.0  10965943.0   Comedy
#
# ...

# %%
zero_value = nomination_df.loc[(nomination_df["Budget"]!=0)]
zero_value
# Out:
#                   Unnamed: 0  \
# Win or Nominated
# N                          1
# N                          4
# N                          7
# N                          8
# N                         10
# N                         12
# N                         13
# N                         19
# N                         20
# N                         22
# N                         25
# N                         28
# N                         29
# N                         31
# N                         39
# N                         40
# N                         41
# N                         43
# N                         44
# N                         49
# N                         51
# N                         53
# N                         54
# N                         55
# N                         57
# N                         60
# N                         61
# N                         62
# N                         64
# N                         66
# ...

# %%
nomination_df = zero_value

# %%
reduced_film_data = nomination_df[["Production Company", "Oscar Wins"]]
reduced_film_data.head()
# Out:
#                            Production Company  Oscar Wins
# Win or Nominated
# N                               Sony Pictures           1
# N                 Warner Independent Pictures           6
# N                          Universal Pictures           3
# N                             New Line Cinema           2
# N                           Weinstein Company           2

# %%
prod_counts = reduced_film_data["Production Company"].value_counts()
prod_counts.head(10)
# Out:
# Warner Bros. Pictures     19
# Universal Pictures        17
# Walt Disney Pictures      17
# 20th Century Fox          16
# Sony Pictures Classics     9
# Sony Pictures              9
# Focus Features             9
# The Weinstein Company      8
# Paramount Pictures         8
# Warner Bros.               5
# Name: Production Company, dtype: int64

# %%
prod_10 = prod_counts.head(10)
prod_10
# Out:
# Warner Bros. Pictures     19
# Universal Pictures        17
# Walt Disney Pictures      17
# 20th Century Fox          16
# Sony Pictures Classics     9
# Sony Pictures              9
# Focus Features             9
# The Weinstein Company      8
# Paramount Pictures         8
# Warner Bros.               5
# Name: Production Company, dtype: int64

# %%
prod_counts.head(15).plot(kind="bar", figsize=(12,5))

# %%
nomination_df.plot(kind='scatter', x='Budget', y='Box Office', c='teal', alpha=0.9)
plt.axis([0,350000000,0,2500000000])
plt.scatter(nomination_df['Budget'], nomination_df['Revenue'],c='green')
plt.grid()
plt.title("Budget vs. Box Office vs. Revenue")
# Out:
# Text(0.5, 1.0, 'Budget vs. Box Office vs. Revenue')

# %%
nomination_df.plot(kind='scatter', x='Budget', y='Revenue', c='blue', alpha=0.9)
plt.axis([0,350000000,0,2500000000])
plt.grid()
plt.title("Budget vs. Revenue")
# Out:
# Text(0.5, 1.0, 'Budget vs. Revenue')

# %%
nomination_df.plot(kind='scatter', x='Budget', y='Box Office', c='green', alpha=0.9)
plt.axis([0,350000000,0,2500000000])
plt.grid()
plt.title("Budget vs. Box Office")
# Out:
# Text(0.5, 1.0, 'Budget vs. Box Office')

# %%
new_data = nomination_df[["Box Office", "Metascore", "wins"]]
new_data
# Out:
#                    Box Office  Metascore  wins
# Win or Nominated
# N                  99165609.0       90.0  70.0
# N                  31500000.0       80.0  38.0
# N                  61600000.0       69.0  16.0
# N                  31500000.0       81.0  37.0
# N                   8713873.0       66.0  32.0
# N                  18324242.0       68.0   6.0
# N                   2416555.0       80.0  21.0
# N                  57300000.0       64.0   8.0
# N                   2591047.0       85.0  29.0
# N                 162586036.0       64.0  11.0
# N                   5307219.0       75.0  20.0
# N                  12830604.0       84.0  60.0
# N                  17400000.0       73.0  15.0
# N                 124700000.0       62.0  16.0
# N                   6585535.0       65.0   2.0
# N                  17114882.0       82.0  28.0
# N                   3900000.0       68.0  25.0
# N                  66636385.0       69.0   5.0
# N                  18173360.0       73.0  23.0
# ...
